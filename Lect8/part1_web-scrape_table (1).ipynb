# %% [markdown]
# # Веб-скрейпинг и таблицы
#
# *Алла Тамбовцева, НИУ ВШЭ*

# %% [markdown]
# **Наша задача:** выгрузить недавние новости в датафрейм `pandas`, чтобы потом сохранить все в csv-файл.
#
# Сначала сгрузим весь html-код страницы и сохраним его в отдельную переменную. Для этого нам понадобится библиотека `requests`. Импортируем её:

# %%
import requests

# %% [markdown]
# Сохраним ссылку на главную страницу сайта в переменную `url` для удобства и выгрузим страницу. (Разумеется, это будет работать при подключении к интернету. Если соединение будет отключено, Python выдаст `NewConnectionError`).

# %%
url = 'https://nplus1.ru/' # сохраняем
page = requests.get(url, ) # загружаем страницу по ссылке

# %% [markdown]
# Если мы просто посмотрим на объект, мы ничего особенного не увидим:

# %%
page  # response 200 - страница загружена
# Out:
# <Response [200]>

# %% [markdown]
# Импортируем функцию `BeautifulSoup` из библиотеки `bs4` (от *beautifulsoup4*) и заберём со страницы `page` код html в виде текста.

# %%
from bs4 import BeautifulSoup  # не спрашивайте, почему BeautifulSoup

# %%
soup = BeautifulSoup(page.text, 'lxml')

# %% [markdown]
# Если выведем `soup` на экран, мы увидим то же самое, что в режиме разработчика или в режиме происмотра исходного кода (`view-source` через *Ctrl+U* в Google Chrome).

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="ru" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>N + 1: научные статьи, новости, открытия</title>
# <link href="/front-build/css/main.css" rel="stylesheet"/>
# <link href="/front-build/css/app.css" rel="stylesheet"/>
# <link href="/images-new/favicon-bw.png" rel="icon"/>
# <link href="https://nplus1.ru" rel="canonical"/>
# <meta content="8c90b02c84ac3b72" name="yandex-verification"/>
# <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>
# <script>window.yaContextCb = window.yaContextCb || []</script>
# <script async="" src="https://yandex.ru/ads/system/context.js"></script>
# <meta content="N + 1: научные статьи, новости, открытия" property="og:site_name"/>
# <meta content="N + 1: научные статьи, новости, открытия" property="og:title"/>
# <meta content="https://nplus1.ru/images-new/share_snippet.png" property="og:image"/>
# <meta content="https://nplus1.ru" property="og:url"/>
# <meta content="N + 1: научные статьи, новости, открытия" property="og:description"/>
# <meta content="" property="og:type"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@nplusodin" name="twitter:site"/>
# <meta content="N + 1: научные статьи, новости, открытия" name="twitter:title"/>
# <meta content="N + 1: научные статьи, новости, открытия" name="twitter:description"/>
# <meta content="https://nplus1.ru/images-new/share_snippet.png" name="twitter:image"/>
# <link href="https://nplus1.ru/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
# </head>
# <body class="antialiased">
# <div class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray" id="appfront">
# <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50" data-ref-header="" ref="headerRef">
# <div class="border-b border-main-gray h-full">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full" data-ref-header-container="" ref="headerContainerRef">
# <button aria-label="Go" class="w-7.5 h-7.5" data-ref-header-menu-btn="" id="topMenuBtn" ref="headerMenuBtnRef">
# <template v-if="isOpenDesktopMenu || isOpenMobileMenu">
# <svg class="w-full h-full">
# <use xlink:href="#n1_cross_menu"></use>
# </svg>
# </template>
# <template v-else="">
# <svg class="w-full h-full">
# <use xlink:href="#n1_burger"></use>
# </svg>
# </template>
# </button>
# <div>
# <img alt="as" height="23" src="/images-new/logo.svg" width="57"/>
# </div>
# <a class="w-7.5 h-7.5" href="/search">
# <svg class="w-full h-full">
# <use xlink:href="#n1_pupa"></use>
# </svg>
# </a>
# </div>
# </div>
# <nav :style="stylesNavDesktop" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden" id="navMenu" v-if="isOpenDesktopMenu">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
# <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">
# <!--
#         <a @click.native="menuClose"
#            class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"
#            href="/lk">
#           <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">
#             <use xlink:href="#n1_person"></use>
#           </svg>
#           <span>Личный кабинет</span>
#         </a>
#         -->
# <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75" href="https://offline.nplus1.ru/">N + offline</a>
# <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75" href="https://nplus.pro/">N + production</a>
# </div>
# <div class="grid grid-cols-12 gap-x-5 gap-y-5 md:gap-y-9 pb-6">
# <div class="col-span-6 md:col-span-3 text-20 lg:text-26 xl:text-34 font-spectral flex flex-col gap-y-3">
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about" target="_blank">
#                 О нас
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#                 Сложность
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#                 Рекламодателям
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#                 Авторам
#               </a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="/search/empty/869">Физика</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/874">Зоология</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/880">Астрономия</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/768">Генетика</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/890">Математика</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/871">Космонавтика</a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="/search/empty/876">Археология</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/775">Нейронауки</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/767">На мышах</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/771">Звук</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/772">Красота</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/778">Научные закрытия</a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="/search/empty/917">ИИ спешит на помощь</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/918">Когда рассеется дым</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/824">Книжная полка</a>
# </div>
# </div>
# <div class="py-12 mt-auto border-t border-gray-2 text-18 grid grid-cols-12 gap-x-5 md:gap-x-9">
# <ul class="flex gap-2.5">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <nav :style="stylesNavMobile" class="relative bg-white max-h-0 n1_top_nav overflow-hidden" id="mobNavMenu" v-if="isOpenMobileMenu">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
# <div class="text-30 font-spectral flex flex-col gap-y-5 mb-10 mt-10">
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about" target="_blank">О
#           нас</a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">Сложность</a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">Рекламодателям</a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/news/2015/09/21/editor-thy-name" target="_blank">Вакансии</a>
# </div>
# <div class="text-28 text-main flex flex-col gap-y-2.5 mb-10">
# <a class="hover:underline transition-colors duration-75" href="/search/empty/869">Физика</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/874">Зоология</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/880">Астрономия</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/768">Генетика</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/890">Математика</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/871">Космонавтика</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/876">Археология</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/775">Нейронауки</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/767">На мышах</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/771">Звук</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/772">Красота</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/778">Научные закрытия</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/917">ИИ спешит на помощь</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/918">Когда рассеется дым</a>
# <a class="hover:underline transition-colors duration-75" href="/search/empty/824">Книжная полка</a>
# </div>
# <div class="max-w-full flex py-5 border-t border-gray-2">
# <div class="flex gap-x-5 overflow-x-auto">
# <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">N + offline</a>
# <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">N + production</a>
# </div>
# </div>
# <div class="pt-5 pb-10 border-t border-gray-2 text-18">
# <ul class="flex gap-2.5">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# </header>
# <section class="mb-10">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto mx-auto">
# <div class="grid grid-cols-2 col-span-2 gap-0.5 n1_m_full n1_fs_main">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/708327/91c22cfb97856eb188ef8a45f7f0aa09.jpg">
# <img alt="Ваше роботакси подъезжает" class="w-full h-full object-cover brightness-75" src="https://app-images.website.yandexcloud.net/708327/91c22cfb97856eb188ef8a45f7f0aa09.jpg" style="background-color: #5916fb"/>
# </source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/708328/895d146a5c87339ac93974cf4f26d210.jpg">
# <img alt="Ваше роботакси подъезжает" class="w-full h-full object-cover brightness-75" src="https://app-images.website.yandexcloud.net/708328/895d146a5c87339ac93974cf4f26d210.jpg" style="background-color: #5916fb"/>
# </source></picture>
# </div>
# </div>
# <a class="absolute bottom-5 inset-x-4 md:inset-x-5" href="https://nplus1.ru/material/2022/10/31/robotaxi-arriving">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Ваше роботакси подъезжает</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#               С какими вызовами столкнулись разработчики автономного транспорта
#             </div>
# </a>
# <div class="absolute top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="/search/empty/812">Партнерский материал</a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="/search/empty/887">Транспорт</a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">3.2</span>
# </a>
# </div>
# </div>
# </div>
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/710742/6e2f526e67c21819be5cf244b9de2f60.jpg">
# <img alt="Черный ворон не пролетал?" class="w-full h-full object-cover brightness-75" src="https://app-images.website.yandexcloud.net/710742/6e2f526e67c21819be5cf244b9de2f60.jpg" style="background-color: #b5b5b3"/>
# </source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/710743/067189bf1c97e7c7bec43348177030ce.jpg">
# <img alt="Черный ворон не пролетал?" class="w-full h-full object-cover brightness-75" src="https://app-images.website.yandexcloud.net/710743/067189bf1c97e7c7bec43348177030ce.jpg" style="background-color: #b5b5b3"/>
# </source></picture>
# </div>
# </div>
# <a class="absolute bottom-5 inset-x-4 md:inset-x-5" href="https://nplus1.ru/blog/2022/10/28/black-raven">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Черный ворон не пролетал?</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#               или Похождения унтер-офицера Веревкина в русском фольклоре
#             </div>
# </a>
# <div class="absolute top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="/search/empty/817">История</a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="/search/empty/877">Антропология</a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">3.4</span>
# </a>
# </div>
# </div>
# </div>
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/711469/52ac358853c1583267746fb609889d7e.jpg">
# <img alt="Следите за мышами: что будет с лекарством за два миллиона долларов после отзыва ключевой статьи" class="w-full h-full object-cover brightness-75" src="https://app-images.website.yandexcloud.net/711469/52ac358853c1583267746fb609889d7e.jpg" style="background-color: #6c1826"/>
# </source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/711470/1d5198f5fc67db1414bdb7c02359d017.jpg">
# <img alt="Следите за мышами: что будет с лекарством за два миллиона долларов после отзыва ключевой статьи" class="w-full h-full object-cover brightness-75" src="https://app-images.website.yandexcloud.net/711470/1d5198f5fc67db1414bdb7c02359d017.jpg" style="background-color: #6c1826"/>
# </source></picture>
# </div>
# </div>
# <a class="absolute bottom-5 inset-x-4 md:inset-x-5" href="https://nplus1.ru/blog/2022/10/28/zolgensma">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Следите за мышами: что будет с лекарством за два миллиона долларов после отзыва ключевой статьи</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
# </div>
# </a>
# <div class="absolute top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="/search/empty/873">Медицина</a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">4.1</span>
# </a>
# </div>
# </div>
# </div>
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/712067/636006428394d_hl_cover_h.gif">
# <img alt="Шмели поиграли шариками" class="w-full h-full object-cover brightness-75" src="https://app-images.website.yandexcloud.net/712067/636006428394d_hl_cover_h.gif" style="background-color: "/>
# </source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/712066/6360064111528_hl_cover_v.gif">
# <img alt="Шмели поиграли шариками" class="w-full h-full object-cover brightness-75" src="https://app-images.website.yandexcloud.net/712066/6360064111528_hl_cover_v.gif" style="background-color: "/>
# </source></picture>
# </div>
# </div>
# <a class="absolute bottom-5 inset-x-4 md:inset-x-5" href="https://nplus1.ru/news/2022/10/31/bombus-terrestris">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Шмели поиграли шариками</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#               Это одно из первых доказательств, что насекомые играют
#             </div>
# </a>
# <div class="absolute top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="/search/empty/874">Зоология</a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/5">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">5.1</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="mb-0 sm:mb-5">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 sm:grid-cols-12 gap-x-5 md:gap-x-9 relative">
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
# <span class="overflow-hidden text-ellipsis whitespace-nowrap">14:35</span>
# </div>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/11/01">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">01.11.22</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/817">
# <p class="truncate">История</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.9</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/11/01/nudes">
# <div>Художники XX и XXI веков изобразили мужчин с большими пенисами</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
# <span class="overflow-hidden text-ellipsis whitespace-nowrap">13:52</span>
# </div>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/11/01">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">01.11.22</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/869">
# <p class="truncate">Физика</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">3.1</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/11/01/why-cats-have-nine-lives">
# <div>Физик объяснил живучесть кошек при падении из окна</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
# <span class="overflow-hidden text-ellipsis whitespace-nowrap">13:00</span>
# </div>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/11/01">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">01.11.22</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/874">
# <p class="truncate">Зоология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">3.1</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/11/01/otus-bikegila">
# <div>Орнитологи описали новый вид сов. Он живет только на африканском острове Принсипи</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
# <span class="overflow-hidden text-ellipsis whitespace-nowrap">11:39</span>
# </div>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/11/01">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">01.11.22</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/877">
# <p class="truncate">Антропология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">3.5</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/11/01/family-in-jar">
# <div>В Корее нашли кувшин с останками раннесредневекового семейства</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
# <span class="overflow-hidden text-ellipsis whitespace-nowrap">09:55</span>
# </div>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/11/01">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">01.11.22</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/873">
# <p class="truncate">Медицина</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.4</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/11/01/mali-malaria-mab">
# <div>Моноклональные антитела против тропической малярии предотвратили три четверти заражений</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/10/31">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">31.10.22</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/880">
# <p class="truncate">Астрономия</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">3.4</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/10/31/echo-hubble">
# <div>«Хаббл» проследил динамику светового эха от вспышки сверхновой</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/10/31">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">31.10.22</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/874">
# <p class="truncate">Зоология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/5">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">5.1</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/10/31/bombus-terrestris">
# <div>Шмели поиграли шариками</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/10/31">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">31.10.22</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/890">
# <p class="truncate">Математика</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/5">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">5.9</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/10/31/marking-model">
# <div>Физики построили модель футбольной опеки</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/10/31">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">31.10.22</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/871">
# <p class="truncate">Космонавтика</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.9</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/10/31/mars-samples">
# <div>NASA и ESA нашли место для склада собранных «Персеверансом» образцов</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/10/31">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">31.10.22</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/880">
# <p class="truncate">Астрономия</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">4.2</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/10/31/hubble-rocky-atmosphere">
# <div>«Хаббл» поискал атмосферу у субземли</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/10/31">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">31.10.22</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/885">
# <p class="truncate">Биология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">4.4</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/10/31/retina-moving">
# <div>Мухи пошевелили сетчаткой и посмотрели по сторонам</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/10/31">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">31.10.22</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/876">
# <p class="truncate">Археология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.5</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/10/31/ephesos">
# <div>В Эфесе обнаружили византийские торговую лавку и закусочную</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="mb-0 sm:mb-10">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 sm:grid-cols-12 gap-x-5 md:gap-x-9">
# <div class="col-span-6">
# <div class="flex flex-col gap-x-9 border-t border-gray-2 pt-5 pb-10 sm:pb-5">
# <a class="shrink-0 h-60 lg:h-72 xl:h-88 relative group" href="https://nplus1.ru/material/2022/10/26/wildlife-photographer-of-the-year-2022-the-winning-images">
# <picture>
# <source media="(max-width: 768px)" srcset="https://app-images.website.yandexcloud.net/709874/63590d088012a_cover_mobile.jpg">
# <source media="(max-width: 1023px)" srcset="https://app-images.website.yandexcloud.net/709873/63590d07ce382_cover_tablet.jpg">
# <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/709872/63590d0706f67_cover.jpg">
# <img alt="Волшебные сморчки, оргия пчел и медведи в поселке-призраке" class="w-full h-full object-cover" src="https://app-images.website.yandexcloud.net/709872/63590d0706f67_cover.jpg" style="background: #a3938a"/>
# </source></source></source></picture>
# </a>
# <div class="flex flex-col">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags xl:pr-9">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/2022/10/26">
# <span class="group-hover:text-main transition-colors duration-75">26.10.22</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/search/empty/874">
# <span class="group-hover:text-main transition-colors duration-75">Зоология</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/search/empty/872">
# <span class="group-hover:text-main transition-colors duration-75">Экология и климат</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">1.5</span>
# </a>
# </div>
# <a class="group" href="https://nplus1.ru/material/2022/10/26/wildlife-photographer-of-the-year-2022-the-winning-images">
# <h3 class="text-34 sm:text-22 lg:text-32 mb-1 transition-colors duration-75 group-hover:text-main">
#                 Волшебные сморчки, оргия пчел и медведи в поселке-призраке</h3>
# <p class="font-spectral text-main-gray text-36 sm:text-24 lg:text-34 transition-colors duration-75 group-hover:text-main">
#                 Победители конкурса Wildlife Photographer of the Year 2022</p>
# </a>
# </div>
# </div>
# </div>
# <div class="col-span-6">
# <div class="flex flex-col gap-x-9 border-t border-gray-2 pt-5 pb-10 sm:pb-5">
# <a class="shrink-0 h-60 lg:h-72 xl:h-88 relative group" href="https://nplus1.ru/blog/2022/10/26/a-planet-of-viruses">
# <picture>
# <source media="(max-width: 768px)" srcset="https://app-images.website.yandexcloud.net/710065/635942af43975_cover_mobile.jpg">
# <source media="(max-width: 1023px)" srcset="https://app-images.website.yandexcloud.net/710064/635942aea530a_cover_tablet.jpg">
# <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/710063/635942add785e_cover.jpg">
# <img alt="«Планета вирусов»" class="w-full h-full object-cover" src="https://app-images.website.yandexcloud.net/710063/635942add785e_cover.jpg" style="background: #eec3c3"/>
# </source></source></source></picture>
# </a>
# <div class="flex flex-col">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags xl:pr-9">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/blog/2022/10/26">
# <span class="group-hover:text-main transition-colors duration-75">26.10.22</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/search/empty/885">
# <span class="group-hover:text-main transition-colors duration-75">Биология</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">1.1</span>
# </a>
# </div>
# <a class="group" href="https://nplus1.ru/blog/2022/10/26/a-planet-of-viruses">
# <h3 class="text-34 sm:text-22 lg:text-32 mb-1 transition-colors duration-75 group-hover:text-main">
#                 «Планета вирусов»</h3>
# <p class="font-spectral text-main-gray text-36 sm:text-24 lg:text-34 transition-colors duration-75 group-hover:text-main">
#                 Что за вирусы обитают в океане и какую роль они играют в эволюции</p>
# </a>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="mb-0 sm:mb-5 grid gap-y-5">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 sm:grid-cols-12 gap-x-5 md:gap-x-9 sm:grid-rows-2 n1_main_template_area" data-live-feed="0">
# <div class="n1_main_area_a">
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/10/31">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">31.10.22</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/869">
# <p class="truncate">Физика</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">4.2</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/10/31/sheep-collective-motion">
# <div>Физики описали коллективное движение овец</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="n1_main_area_b">
# ...
# <p>Связь с редакцией: <a href="mailto:info@nplus1.ru">info@nplus1.ru</a></p></div>
# </div>
# <div class="order-5 col-span-6 sm:col-span-9 sm:col-start-4 lg:col-span-5 text-gray-2 text-16 leading-none flex flex-col">
# <a class="underline transition-colors duration-75 hover:text-main inline-block col-span-6 sm:col-span-5 mb-5 font-spectral italic" href="/personal-data-policy">Политика
#           обработки
#           персональных данных пользователей сайта
#         </a>
# </div>
# <div class="order-3 sm:col-span-9 lg:col-span-5 sm:order-3 lg:order-6 mt-auto col-span-6 mb-10 lg:mb-0">
# <ul class="flex gap-3 text-gray-2">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <svg class="stroke-current" fill="none" height="16" id="n1_star" style="display:block;width:0;height:0" viewbox="3 3 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M11 5V17"></path>
# <path d="M6.75781 6.75781L15.2431 15.2431"></path>
# <path d="M17 11L5 11"></path>
# <path d="M15.2422 6.75781L6.75691 15.2431"></path>
# </svg>
# <svg class="stroke-current" fill="none" id="n1_person" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <circle cx="25" cy="25" r="24.5"></circle>
# <path d="M30.1897 30.3212C28.9483 29.9852 27.5345 29.7164 27.5345 28.5067C27.5345 27.8347 27.5 27.0618 28.2931 26.625C31.0172 25.0457 32.5 22.3911 32.1552 18.2581C31.8103 14.0578 29.2586 11 24.9828 11C20.7069 11 18.1552 14.0578 17.8103 18.2581C17.4655 22.3911 18.9138 25.0457 21.6724 26.625C22.4655 27.0618 22.431 27.8347 22.431 28.5067C22.431 29.7164 21.0172 29.9516 19.8103 30.3212C17.3966 30.9933 12.5 31.9005 12.5 36C16.431 36 33.569 36 37.5 36C37.4655 31.9005 32.6034 30.9933 30.1897 30.3212Z" stroke-miterlimit="10"></path>
# </svg>
# <svg fill="none" id="n1_tg" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M16.3181 21.32H19.4961V30H20.7141V21.32H23.8921V20.2H16.3181V21.32ZM28.6969 30.084C30.3769 30.084 31.4269 29.286 31.8749 28.572L31.9589 30H33.0089V24.694H28.8789V25.814H31.8189V26.15C31.8189 27.886 30.5169 28.964 28.7109 28.964C26.6809 28.964 25.3369 27.368 25.3369 25.1C25.3369 22.832 26.6809 21.236 28.7389 21.236C30.2229 21.236 31.2729 22.034 31.6089 23.392H32.9109C32.5749 21.376 30.9369 20.116 28.7669 20.116C25.9249 20.116 24.0909 22.132 24.0909 25.1C24.0909 28.068 25.9809 30.084 28.6969 30.084Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_vk" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M19.8015 30H21.2715L24.7995 20.2H23.5395L20.5575 28.558L17.5615 20.2H16.2735L19.8015 30ZM25.8768 30H27.0948V27.452L29.0408 25.254L32.3448 30H33.8008L29.9368 24.33L33.5208 20.2H32.0368L27.0948 25.758V20.2H25.8768V30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_ok" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M25.2125 25.1C25.2125 22.216 23.2945 20.116 20.5365 20.116C17.7785 20.116 15.8605 22.216 15.8605 25.1C15.8605 27.984 17.7785 30.084 20.5365 30.084C23.2945 30.084 25.2125 27.984 25.2125 25.1ZM17.1065 25.1C17.1065 22.846 18.4925 21.236 20.5365 21.236C22.5805 21.236 23.9665 22.846 23.9665 25.1C23.9665 27.354 22.5805 28.964 20.5365 28.964C18.4925 28.964 17.1065 27.354 17.1065 25.1ZM26.7518 30H27.9698V27.452L29.9158 25.254L33.2198 30H34.6758L30.8118 24.33L34.3958 20.2H32.9118L27.9698 25.758V20.2H26.7518V30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_tw" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M14.4792 21.32H17.6572V30H18.8752V21.32H22.0532V20.2H14.4792V21.32ZM25.332 30H26.788L29.014 22.23L31.254 30H32.71L35.58 20.2H34.32L32.01 28.432L29.686 20.2H28.454L26.046 28.432L23.75 20.2H22.476L25.332 30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg height="64px" id="n1_infinity" preserveaspectratio="xMidYMid" style="display:block;width:0;height:0" viewbox="0 0 100 100" width="64px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <path d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z" fill="none" stroke="#ffffff" stroke-dasharray="146.25568908691406 110.33323913574219" stroke-linecap="round" stroke-width="5" style="transform:scale(0.8);transform-origin:50px 50px">
# <animate attributename="stroke-dashoffset" dur="1.3157894736842106s" keytimes="0;1" repeatcount="indefinite" values="0;256.58892822265625"></animate>
# </path>
# </svg>
# <svg fill="none" id="n1_cross" style="display:block;width:0;height:0" viewbox="0 0 14 14" xmlns="http://www.w3.org/2000/svg">
# <path d="M1.00146 1L13.0015 13" stroke="#F9F9F9"></path>
# <path d="M13 1L1 13" stroke="#F9F9F9"></path>
# </svg>
# <svg id="n1_link_arrow" style="display:block;width:0;height:0" viewbox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
# <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z" fill="currentColor"></path>
# </svg>
# <svg id="n1_big_star" style="display:block;width:0;height:0;" viewbox="0 0 61 61" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" clip-rule="evenodd" d="M3 29.7729H29.0656L10.6345 11.3418L11.3416 10.6347L29.7728 29.0658V3H30.7728V29.0658L49.2039 10.6347L49.911 11.3418L31.4799 29.7729H57.5455V30.7729H31.4799L49.9111 49.2042L49.204 49.9113L30.7728 31.4801V57.5455H29.7728V31.4801L11.3415 49.9113L10.6344 49.2042L29.0656 30.7729H3V29.7729Z" fill-rule="evenodd"></path>
# <path class="fill-current" d="M29.0656 29.7729V32.2729H35.1012L30.8334 28.0052L29.0656 29.7729ZM3 29.7729V27.2729H0.5V29.7729H3ZM10.6345 11.3418L8.86676 9.57407L7.099 11.3418L8.86676 13.1096L10.6345 11.3418ZM11.3416 10.6347L13.1094 8.86696L11.3416 7.09919L9.57387 8.86696L11.3416 10.6347ZM29.7728 29.0658L28.005 30.8336L32.2728 35.1014V29.0658H29.7728ZM29.7728 3V0.5H27.2728V3H29.7728ZM30.7728 3H33.2728V0.5H30.7728V3ZM30.7728 29.0658H28.2728V35.1014L32.5405 30.8336L30.7728 29.0658ZM49.2039 10.6347L50.9716 8.86696L49.2039 7.09919L47.4361 8.86696L49.2039 10.6347ZM49.911 11.3418L51.6787 13.1096L53.4465 11.3418L51.6787 9.57407L49.911 11.3418ZM31.4799 29.7729L29.7121 28.0052L25.4443 32.2729H31.4799V29.7729ZM57.5455 29.7729H60.0455V27.2729H57.5455V29.7729ZM57.5455 30.7729V33.2729H60.0455V30.7729H57.5455ZM31.4799 30.7729V28.2729H25.4443L29.7121 32.5407L31.4799 30.7729ZM49.9111 49.2042L51.6789 50.972L53.4466 49.2042L51.6789 47.4364L49.9111 49.2042ZM49.204 49.9113L47.4362 51.6791L49.204 53.4468L50.9718 51.6791L49.204 49.9113ZM30.7728 31.4801L32.5405 29.7123L28.2728 25.4445V31.4801H30.7728ZM30.7728 57.5455V60.0455H33.2728V57.5455H30.7728ZM29.7728 57.5455H27.2728V60.0455H29.7728V57.5455ZM29.7728 31.4801H32.2728V25.4445L28.005 29.7123L29.7728 31.4801ZM11.3415 49.9113L9.57374 51.6791L11.3415 53.4468L13.1093 51.6791L11.3415 49.9113ZM10.6344 49.2042L8.86664 47.4364L7.09887 49.2042L8.86664 50.972L10.6344 49.2042ZM29.0656 30.7729L30.8334 32.5407L35.1012 28.2729H29.0656V30.7729ZM3 30.7729H0.5V33.2729H3V30.7729ZM29.0656 27.2729H3V32.2729H29.0656V27.2729ZM8.86676 13.1096L27.2979 31.5407L30.8334 28.0052L12.4023 9.57407L8.86676 13.1096ZM9.57387 8.86696L8.86676 9.57407L12.4023 13.1096L13.1094 12.4025L9.57387 8.86696ZM31.5405 27.2981L13.1094 8.86696L9.57387 12.4025L28.005 30.8336L31.5405 27.2981ZM27.2728 3V29.0658H32.2728V3H27.2728ZM30.7728 0.5H29.7728V5.5H30.7728V0.5ZM33.2728 29.0658V3H28.2728V29.0658H33.2728ZM32.5405 30.8336L50.9716 12.4025L47.4361 8.86696L29.005 27.2981L32.5405 30.8336ZM47.4361 12.4025L48.1432 13.1096L51.6787 9.57407L50.9716 8.86696L47.4361 12.4025ZM48.1432 9.57407L29.7121 28.0052L33.2476 31.5407L51.6787 13.1096L48.1432 9.57407ZM57.5455 27.2729H31.4799V32.2729H57.5455V27.2729ZM60.0455 30.7729V29.7729H55.0455V30.7729H60.0455ZM31.4799 33.2729H57.5455V28.2729H31.4799V33.2729ZM51.6789 47.4364L33.2476 29.0052L29.7121 32.5407L48.1433 50.972L51.6789 47.4364ZM50.9718 51.6791L51.6789 50.972L48.1433 47.4364L47.4362 48.1435L50.9718 51.6791ZM29.005 33.2478L47.4362 51.6791L50.9718 48.1435L32.5405 29.7123L29.005 33.2478ZM33.2728 57.5455V31.4801H28.2728V57.5455H33.2728ZM29.7728 60.0455H30.7728V55.0455H29.7728V60.0455ZM27.2728 31.4801V57.5455H32.2728V31.4801H27.2728ZM28.005 29.7123L9.57374 48.1435L13.1093 51.6791L31.5405 33.2478L28.005 29.7123ZM13.1093 48.1435L12.4022 47.4364L8.86664 50.972L9.57374 51.6791L13.1093 48.1435ZM12.4022 50.972L30.8334 32.5407L27.2979 29.0052L8.86664 47.4364L12.4022 50.972ZM3 33.2729H29.0656V28.2729H3V33.2729ZM0.5 29.7729V30.7729H5.5V29.7729H0.5Z"></path>
# </svg>
# <svg class="stroke-current" fill="none" id="n1_circle_arrow" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <rect height="29" rx="14.5" transform="rotate(-180 29.5 29.5)" width="29" x="29.5" y="29.5"></rect>
# <path d="M9.33985 14.7014L14.6198 19.9414L15.2598 19.3014L11.1198 15.1614L20.3398 15.1614L20.3398 14.2214L11.1198 14.2214L15.2598 10.0814L14.6198 9.44141L9.33985 14.7014Z"></path>
# </svg>
# <svg fill="none" id="n1_circle_arrow_solid" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <mask id="path-1-inside-1_2694_77554">
# <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill-rule="evenodd"></path>
# </mask>
# <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill="#fff" fill-rule="evenodd"></path>
# <path d="M20.6592 15.3001L21.3649 16.0085L22.0774 15.2987L21.3636 14.5903L20.6592 15.3001ZM15.3792 10.0601L16.0836 9.35027L15.3765 8.64853L14.6721 9.35295L15.3792 10.0601ZM15.3792 20.5601L14.6721 21.2672L15.3778 21.9729L16.0849 21.2685L15.3792 20.5601ZM14.7392 19.9201L14.0321 19.213L13.325 19.9201L14.0321 20.6272L14.7392 19.9201ZM18.8792 15.7801L19.5863 16.4872L21.2934 14.7801H18.8792V15.7801ZM9.65918 15.7801H8.65918V16.7801H9.65918V15.7801ZM9.65918 14.8401V13.8401H8.65918V14.8401H9.65918ZM18.8792 14.8401V15.8401H21.2934L19.5863 14.133L18.8792 14.8401ZM14.7392 10.7001L14.0321 9.99295L13.325 10.7001L14.0321 11.4072L14.7392 10.7001ZM1 15C1 7.26801 7.26801 1 15 1V-1C6.16344 -1 -1 6.16344 -1 15H1ZM15 29C7.26801 29 1 22.732 1 15H-1C-1 23.8366 6.16344 31 15 31V29ZM29 15C29 22.732 22.732 29 15 29V31C23.8366 31 31 23.8366 31 15H29ZM15 1C22.732 1 29 7.26801 29 15H31C31 6.16344 23.8366 -1 15 -1V1ZM21.3636 14.5903L16.0836 9.35027L14.6748 10.7698L19.9548 16.0098L21.3636 14.5903ZM16.0849 21.2685L21.3649 16.0085L19.9534 14.5916L14.6734 19.8516L16.0849 21.2685ZM14.0321 20.6272L14.6721 21.2672L16.0863 19.853L15.4463 19.213L14.0321 20.6272ZM18.1721 15.073L14.0321 19.213L15.4463 20.6272L19.5863 16.4872L18.1721 15.073ZM9.65918 16.7801H18.8792V14.7801H9.65918V16.7801ZM8.65918 14.8401V15.7801H10.6592V14.8401H8.65918ZM18.8792 13.8401H9.65918V15.8401H18.8792V13.8401ZM14.0321 11.4072L18.1721 15.5472L19.5863 14.133L15.4463 9.99295L14.0321 11.4072ZM14.6721 9.35295L14.0321 9.99295L15.4463 11.4072L16.0863 10.7672L14.6721 9.35295Z" fill="#fff" mask="url(#path-1-inside-1_2694_77554)"></path>
# </svg>
# <svg fill="none" id="n1_play" style="display:block;width:0;height:0;" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# <path class="stroke-current" d="M18 35V15L36 25L18 35Z"></path>
# </svg>
# <svg fill="none" id="n1_pupa" style="display:block;width:0;height:0;" viewbox="0 0 24 23" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M17 8.80329C17 13.0922 13.4392 16.6066 9 16.6066C4.56077 16.6066 1 13.0922 1 8.80329C1 4.51437 4.56077 1 9 1C13.4392 1 17 4.51437 17 8.80329ZM14.9967 15.3678C13.4049 16.7601 11.3035 17.6066 9 17.6066C4.02944 17.6066 0 13.6652 0 8.80329C0 3.94137 4.02944 0 9 0C13.9706 0 18 3.94137 18 8.80329C18 11.0562 17.1348 13.1114 15.7118 14.6684L23.3531 22.1427C23.5505 22.3358 23.554 22.6524 23.3609 22.8498C23.1678 23.0472 22.8513 23.0507 22.6539 22.8576L14.9967 15.3678Z" fill="#32363A" fill-rule="evenodd"></path>
# </svg>
# <svg fill="none" id="n1_burger" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <line stroke="#32363A" x2="30" y1="6.5" y2="6.5"></line>
# <line stroke="#32363A" x2="30" y1="23.5" y2="23.5"></line>
# <line stroke="#32363A" x2="30" y1="15" y2="15"></line>
# </svg>
# <svg fill="none" id="n1_cross_menu" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <path d="M4 4L26 26" stroke="#32363A"></path>
# <path d="M26 4L4 26" stroke="#32363A"></path>
# </svg>
# <svg id="n1_check" style="display:block;width:0;height:0;fill:currentColor" version="1.1" viewbox="0 0 752 752" xmlns="http://www.w3.org/2000/svg">
# <path d="m183.6 357.87-22.184 22.168v0.003907c-3.2969 3.293-3.2969 8.6367 0 11.934l133.29 133.28v0.003907c3.7305 3.7266 8.7891 5.8242 14.066 5.8242 5.2734 0 10.332-2.0977 14.062-5.8242l267.76-267.76c1.582-1.582 2.4727-3.7305 2.4727-5.9688 0-2.2383-0.89062-4.3867-2.4727-5.9688l-22.156-22.168c-1.582-1.5898-3.7344-2.4805-5.9727-2.4805-2.2422 0-4.3945 0.89062-5.9766 2.4805l-244.31 244.3c-1.8828 1.8789-4.9336 1.8789-6.8164 0l-109.84-109.83c-3.293-3.2852-8.625-3.2852-11.918 0z"></path>
# </svg>
# <script src="/front-build/js/app.js?v=2"></script>
# <!-- Yandex.Metrika counter 2-->
# <script type="text/javascript">
# (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(88946384, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true
# });
#
#
# ym(29654565, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash:true,
# 	ecommerce:"dataLayer"
# });
# </script>
# <noscript>
# <div>
# <img alt="" src="https://mc.yandex.ru/watch/88946384" style="position:absolute; left:-9999px;"/>
# <img alt="" src="https://mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;"/>
# </div>
# </noscript>
# <!-- /Yandex.Metrika counter -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-61773772-1"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-61773772-1');
# </script>
# <script>
# if ('serviceWorker' in navigator) {
# 	window.addEventListener('load', () => {
# 		navigator.serviceWorker.register('/front-service-worker.js').then(reg => {
# 			// sometime later…
# 			reg.update()
# 		})
# 	})
# }
# </script>
# </body>
# </html>

# %% [markdown]
# Для просмотра выглядит не очень удобно.  «Причешем» наш `soup` – воспользуемся методом `.prettify()` в сочетании с функцией `print()`.

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ru" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    N + 1: научные статьи, новости, открытия
#   </title>
#   <link href="/front-build/css/main.css" rel="stylesheet"/>
#   <link href="/front-build/css/app.css" rel="stylesheet"/>
#   <link href="/images-new/favicon-bw.png" rel="icon"/>
#   <link href="https://nplus1.ru" rel="canonical"/>
#   <meta content="8c90b02c84ac3b72" name="yandex-verification"/>
#   <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>
#   <script>
#    window.yaContextCb = window.yaContextCb || []
#   </script>
#   <script async="" src="https://yandex.ru/ads/system/context.js">
#   </script>
#   <meta content="N + 1: научные статьи, новости, открытия" property="og:site_name"/>
#   <meta content="N + 1: научные статьи, новости, открытия" property="og:title"/>
#   <meta content="https://nplus1.ru/images-new/share_snippet.png" property="og:image"/>
#   <meta content="https://nplus1.ru" property="og:url"/>
#   <meta content="N + 1: научные статьи, новости, открытия" property="og:description"/>
#   <meta content="" property="og:type"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@nplusodin" name="twitter:site"/>
#   <meta content="N + 1: научные статьи, новости, открытия" name="twitter:title"/>
#   <meta content="N + 1: научные статьи, новости, открытия" name="twitter:description"/>
#   <meta content="https://nplus1.ru/images-new/share_snippet.png" name="twitter:image"/>
#   <link href="https://nplus1.ru/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
#  </head>
#  <body class="antialiased">
#   <div class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray" id="appfront">
#    <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50" data-ref-header="" ref="headerRef">
#     <div class="border-b border-main-gray h-full">
#      <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full" data-ref-header-container="" ref="headerContainerRef">
#       <button aria-label="Go" class="w-7.5 h-7.5" data-ref-header-menu-btn="" id="topMenuBtn" ref="headerMenuBtnRef">
#        <template v-if="isOpenDesktopMenu || isOpenMobileMenu">
#         <svg class="w-full h-full">
#          <use xlink:href="#n1_cross_menu">
#          </use>
#         </svg>
#        </template>
#        <template v-else="">
#         <svg class="w-full h-full">
#          <use xlink:href="#n1_burger">
#          </use>
#         </svg>
#        </template>
#       </button>
#       <div>
#        <img alt="as" height="23" src="/images-new/logo.svg" width="57"/>
#       </div>
#       <a class="w-7.5 h-7.5" href="/search">
#        <svg class="w-full h-full">
#         <use xlink:href="#n1_pupa">
#         </use>
#        </svg>
#       </a>
#      </div>
#     </div>
#     <nav :style="stylesNavDesktop" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden" id="navMenu" v-if="isOpenDesktopMenu">
#      <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#       <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">
#        <!--
#         <a @click.native="menuClose"
#            class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"
#            href="/lk">
#           <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">
#             <use xlink:href="#n1_person"></use>
#           </svg>
#           <span>Личный кабинет</span>
#         </a>
#         -->
#        <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75" href="https://offline.nplus1.ru/">
#         N + offline
#        </a>
#        <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75" href="https://nplus.pro/">
#         N + production
#        </a>
#       </div>
#       <div class="grid grid-cols-12 gap-x-5 gap-y-5 md:gap-y-9 pb-6">
#        <div class="col-span-6 md:col-span-3 text-20 lg:text-26 xl:text-34 font-spectral flex flex-col gap-y-3">
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about" target="_blank">
#          О нас
#         </a>
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#          Сложность
#         </a>
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#          Рекламодателям
#         </a>
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#          Авторам
#         </a>
#        </div>
#        <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#         <a class="hover:underline transition-colors duration-75" href="/search/empty/869">
#          Физика
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="/search/empty/874">
#          Зоология
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="/search/empty/880">
#          Астрономия
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="/search/empty/768">
#          Генетика
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="/search/empty/890">
#          Математика
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="/search/empty/871">
#          Космонавтика
#         </a>
#        </div>
#        <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#         <a class="hover:underline transition-colors duration-75" href="/search/empty/876">
#          Археология
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="/search/empty/775">
#          Нейронауки
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="/search/empty/767">
#          На мышах
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="/search/empty/771">
#          Звук
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="/search/empty/772">
#          Красота
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="/search/empty/778">
#          Научные закрытия
#         </a>
#        </div>
#        <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#         <a class="hover:underline transition-colors duration-75" href="/search/empty/917">
#          ИИ спешит на помощь
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="/search/empty/918">
#          Когда рассеется дым
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="/search/empty/824">
#          Книжная полка
#         </a>
#        </div>
#       </div>
#       <div class="py-12 mt-auto border-t border-gray-2 text-18 grid grid-cols-12 gap-x-5 md:gap-x-9">
#        <ul class="flex gap-2.5">
#         <li>
#          <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_tg">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_vk">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_ok">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li class="w-12">
#          <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_tw">
#            </use>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </nav>
#     <nav :style="stylesNavMobile" class="relative bg-white max-h-0 n1_top_nav overflow-hidden" id="mobNavMenu" v-if="isOpenMobileMenu">
#      <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#       <div class="text-30 font-spectral flex flex-col gap-y-5 mb-10 mt-10">
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about" target="_blank">
#         О
#           нас
#        </a>
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#         Сложность
#        </a>
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#         Рекламодателям
#        </a>
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/news/2015/09/21/editor-thy-name" target="_blank">
#         Вакансии
#        </a>
#       </div>
#       <div class="text-28 text-main flex flex-col gap-y-2.5 mb-10">
#        <a class="hover:underline transition-colors duration-75" href="/search/empty/869">
#         Физика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="/search/empty/874">
#         Зоология
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="/search/empty/880">
#         Астрономия
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="/search/empty/768">
#         Генетика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="/search/empty/890">
#         Математика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="/search/empty/871">
#         Космонавтика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="/search/empty/876">
#         Археология
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="/search/empty/775">
#         Нейронауки
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="/search/empty/767">
#         На мышах
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="/search/empty/771">
#         Звук
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="/search/empty/772">
#         Красота
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="/search/empty/778">
#         Научные закрытия
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="/search/empty/917">
#         ИИ спешит на помощь
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="/search/empty/918">
#         Когда рассеется дым
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="/search/empty/824">
#         Книжная полка
#        </a>
#       </div>
#       <div class="max-w-full flex py-5 border-t border-gray-2">
#        <div class="flex gap-x-5 overflow-x-auto">
#         <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">
#          N + offline
#         </a>
#         <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">
#          N + production
#         </a>
#        </div>
#       </div>
#       <div class="pt-5 pb-10 border-t border-gray-2 text-18">
#        <ul class="flex gap-2.5">
#         <li>
#          <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_tg">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_vk">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_ok">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li class="w-12">
#          <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_tw">
#            </use>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </nav>
#    </header>
#    <section class="mb-10">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto mx-auto">
#      <div class="grid grid-cols-2 col-span-2 gap-0.5 n1_m_full n1_fs_main">
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="hidden sm:block max-height-[333px]">
#         <div class="-inset-0.5 absolute group">
#          <picture>
#           <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/708327/91c22cfb97856eb188ef8a45f7f0aa09.jpg">
#            <img alt="Ваше роботакси подъезжает" class="w-full h-full object-cover brightness-75" src="https://app-images.website.yandexcloud.net/708327/91c22cfb97856eb188ef8a45f7f0aa09.jpg" style="background-color: #5916fb"/>
#           </source>
#          </picture>
#         </div>
#        </div>
#        <div class="block sm:hidden">
#         <div class="-inset-0.5 absolute max-height-[333px]">
#          <picture>
#           <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/708328/895d146a5c87339ac93974cf4f26d210.jpg">
#            <img alt="Ваше роботакси подъезжает" class="w-full h-full object-cover brightness-75" src="https://app-images.website.yandexcloud.net/708328/895d146a5c87339ac93974cf4f26d210.jpg" style="background-color: #5916fb"/>
#           </source>
#          </picture>
#         </div>
#        </div>
#        <a class="absolute bottom-5 inset-x-4 md:inset-x-5" href="https://nplus1.ru/material/2022/10/31/robotaxi-arriving">
#         <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#          Ваше роботакси подъезжает
#         </h3>
#         <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#          С какими вызовами столкнулись разработчики автономного транспорта
#         </div>
#        </a>
#        <div class="absolute top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="/search/empty/812">
#           Партнерский материал
#          </a>
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="/search/empty/887">
#           Транспорт
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            3.2
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="hidden sm:block max-height-[333px]">
#         <div class="-inset-0.5 absolute group">
#          <picture>
#           <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/710742/6e2f526e67c21819be5cf244b9de2f60.jpg">
#            <img alt="Черный ворон не пролетал?" class="w-full h-full object-cover brightness-75" src="https://app-images.website.yandexcloud.net/710742/6e2f526e67c21819be5cf244b9de2f60.jpg" style="background-color: #b5b5b3"/>
#           </source>
#          </picture>
#         </div>
#        </div>
#        <div class="block sm:hidden">
#         <div class="-inset-0.5 absolute max-height-[333px]">
#          <picture>
#           <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/710743/067189bf1c97e7c7bec43348177030ce.jpg">
#            <img alt="Черный ворон не пролетал?" class="w-full h-full object-cover brightness-75" src="https://app-images.website.yandexcloud.net/710743/067189bf1c97e7c7bec43348177030ce.jpg" style="background-color: #b5b5b3"/>
#           </source>
#          </picture>
#         </div>
#        </div>
#        <a class="absolute bottom-5 inset-x-4 md:inset-x-5" href="https://nplus1.ru/blog/2022/10/28/black-raven">
#         <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#          Черный ворон не пролетал?
#         </h3>
#         <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#          или Похождения унтер-офицера Веревкина в русском фольклоре
#         </div>
#        </a>
#        <div class="absolute top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="/search/empty/817">
#           История
#          </a>
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="/search/empty/877">
#           Антропология
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            3.4
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="hidden sm:block max-height-[333px]">
#         <div class="-inset-0.5 absolute group">
#          <picture>
#           <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/711469/52ac358853c1583267746fb609889d7e.jpg">
#            <img alt="Следите за мышами: что будет с лекарством за два миллиона долларов после отзыва ключевой статьи" class="w-full h-full object-cover brightness-75" src="https://app-images.website.yandexcloud.net/711469/52ac358853c1583267746fb609889d7e.jpg" style="background-color: #6c1826"/>
#           </source>
#          </picture>
#         </div>
#        </div>
#        <div class="block sm:hidden">
#         <div class="-inset-0.5 absolute max-height-[333px]">
#          <picture>
#           <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/711470/1d5198f5fc67db1414bdb7c02359d017.jpg">
#            <img alt="Следите за мышами: что будет с лекарством за два миллиона долларов после отзыва ключевой статьи" class="w-full h-full object-cover brightness-75" src="https://app-images.website.yandexcloud.net/711470/1d5198f5fc67db1414bdb7c02359d017.jpg" style="background-color: #6c1826"/>
#           </source>
#          </picture>
#         </div>
#        </div>
#        <a class="absolute bottom-5 inset-x-4 md:inset-x-5" href="https://nplus1.ru/blog/2022/10/28/zolgensma">
#         <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#          Следите за мышами: что будет с лекарством за два миллиона долларов после отзыва ключевой статьи
#         </h3>
#         <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#         </div>
#        </a>
#        <div class="absolute top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="/search/empty/873">
#           Медицина
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/4">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            4.1
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="hidden sm:block max-height-[333px]">
#         <div class="-inset-0.5 absolute group">
#          <picture>
#           <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/712067/636006428394d_hl_cover_h.gif">
#            <img alt="Шмели поиграли шариками" class="w-full h-full object-cover brightness-75" src="https://app-images.website.yandexcloud.net/712067/636006428394d_hl_cover_h.gif" style="background-color: "/>
#           </source>
#          </picture>
#         </div>
#        </div>
#        <div class="block sm:hidden">
#         <div class="-inset-0.5 absolute max-height-[333px]">
#          <picture>
#           <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/712066/6360064111528_hl_cover_v.gif">
#            <img alt="Шмели поиграли шариками" class="w-full h-full object-cover brightness-75" src="https://app-images.website.yandexcloud.net/712066/6360064111528_hl_cover_v.gif" style="background-color: "/>
#           </source>
#          </picture>
#         </div>
#        </div>
#        <a class="absolute bottom-5 inset-x-4 md:inset-x-5" href="https://nplus1.ru/news/2022/10/31/bombus-terrestris">
#         <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#          Шмели поиграли шариками
#         </h3>
#         <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#          Это одно из первых доказательств, что насекомые играют
#         </div>
#        </a>
#        <div class="absolute top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="/search/empty/874">
#           Зоология
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/5">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            5.1
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </section>
#    <section class="mb-0 sm:mb-5">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 sm:grid-cols-12 gap-x-5 md:gap-x-9 relative">
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
#           <span class="overflow-hidden text-ellipsis whitespace-nowrap">
#            14:35
#           </span>
#          </div>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/11/01">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            01.11.22
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/817">
#           <p class="truncate">
#            История
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            2.9
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/11/01/nudes">
#          <div>
#           Художники XX и XXI веков изобразили мужчин с большими пенисами
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
#           <span class="overflow-hidden text-ellipsis whitespace-nowrap">
#            13:52
#           </span>
#          </div>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/11/01">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            01.11.22
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/869">
#           <p class="truncate">
#            Физика
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            3.1
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/11/01/why-cats-have-nine-lives">
#          <div>
#           Физик объяснил живучесть кошек при падении из окна
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
#           <span class="overflow-hidden text-ellipsis whitespace-nowrap">
#            13:00
#           </span>
#          </div>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/11/01">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            01.11.22
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/874">
#           <p class="truncate">
#            Зоология
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            3.1
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/11/01/otus-bikegila">
#          <div>
#           Орнитологи описали новый вид сов. Он живет только на африканском острове Принсипи
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
#           <span class="overflow-hidden text-ellipsis whitespace-nowrap">
#            11:39
#           </span>
#          </div>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/11/01">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            01.11.22
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/877">
#           <p class="truncate">
#            Антропология
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            3.5
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/11/01/family-in-jar">
#          <div>
#           В Корее нашли кувшин с останками раннесредневекового семейства
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <div class="inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full">
#           <span class="overflow-hidden text-ellipsis whitespace-nowrap">
#            09:55
#           </span>
#          </div>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/11/01">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            01.11.22
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/873">
#           <p class="truncate">
#            Медицина
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            2.4
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/11/01/mali-malaria-mab">
#          <div>
#           Моноклональные антитела против тропической малярии предотвратили три четверти заражений
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/10/31">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            31.10.22
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/880">
#           <p class="truncate">
#            Астрономия
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            3.4
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/10/31/echo-hubble">
#          <div>
#           «Хаббл» проследил динамику светового эха от вспышки сверхновой
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/10/31">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            31.10.22
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/874">
#           <p class="truncate">
#            Зоология
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/5">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            5.1
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/10/31/bombus-terrestris">
#          <div>
#           Шмели поиграли шариками
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/10/31">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            31.10.22
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/890">
#           <p class="truncate">
#            Математика
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/5">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            5.9
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/10/31/marking-model">
#          <div>
#           Физики построили модель футбольной опеки
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/10/31">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            31.10.22
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/871">
#           <p class="truncate">
#            Космонавтика
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            1.9
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/10/31/mars-samples">
#          <div>
#           NASA и ESA нашли место для склада собранных «Персеверансом» образцов
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/10/31">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            31.10.22
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/880">
#           <p class="truncate">
#            Астрономия
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            4.2
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/10/31/hubble-rocky-atmosphere">
#          <div>
#           «Хаббл» поискал атмосферу у субземли
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/10/31">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            31.10.22
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/885">
#           <p class="truncate">
#            Биология
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            4.4
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2022/10/31/retina-moving">
#          <div>
#           Мухи пошевелили сетчаткой и посмотрели по сторонам
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2022/10/31">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            31.10.22
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="/search/empty/876">
#           <p class="truncate">
#            Археология
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
# ...
#        <ul class="flex gap-3 text-gray-2">
#         <li>
#          <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_tg">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_vk">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_ok">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li class="w-12">
#          <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_tw">
#            </use>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <svg class="stroke-current" fill="none" height="16" id="n1_star" style="display:block;width:0;height:0" viewbox="3 3 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#    <path d="M11 5V17">
#    </path>
#    <path d="M6.75781 6.75781L15.2431 15.2431">
#    </path>
#    <path d="M17 11L5 11">
#    </path>
#    <path d="M15.2422 6.75781L6.75691 15.2431">
#    </path>
#   </svg>
#   <svg class="stroke-current" fill="none" id="n1_person" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <circle cx="25" cy="25" r="24.5">
#    </circle>
#    <path d="M30.1897 30.3212C28.9483 29.9852 27.5345 29.7164 27.5345 28.5067C27.5345 27.8347 27.5 27.0618 28.2931 26.625C31.0172 25.0457 32.5 22.3911 32.1552 18.2581C31.8103 14.0578 29.2586 11 24.9828 11C20.7069 11 18.1552 14.0578 17.8103 18.2581C17.4655 22.3911 18.9138 25.0457 21.6724 26.625C22.4655 27.0618 22.431 27.8347 22.431 28.5067C22.431 29.7164 21.0172 29.9516 19.8103 30.3212C17.3966 30.9933 12.5 31.9005 12.5 36C16.431 36 33.569 36 37.5 36C37.4655 31.9005 32.6034 30.9933 30.1897 30.3212Z" stroke-miterlimit="10">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_tg" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M16.3181 21.32H19.4961V30H20.7141V21.32H23.8921V20.2H16.3181V21.32ZM28.6969 30.084C30.3769 30.084 31.4269 29.286 31.8749 28.572L31.9589 30H33.0089V24.694H28.8789V25.814H31.8189V26.15C31.8189 27.886 30.5169 28.964 28.7109 28.964C26.6809 28.964 25.3369 27.368 25.3369 25.1C25.3369 22.832 26.6809 21.236 28.7389 21.236C30.2229 21.236 31.2729 22.034 31.6089 23.392H32.9109C32.5749 21.376 30.9369 20.116 28.7669 20.116C25.9249 20.116 24.0909 22.132 24.0909 25.1C24.0909 28.068 25.9809 30.084 28.6969 30.084Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg fill="none" id="n1_vk" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M19.8015 30H21.2715L24.7995 20.2H23.5395L20.5575 28.558L17.5615 20.2H16.2735L19.8015 30ZM25.8768 30H27.0948V27.452L29.0408 25.254L32.3448 30H33.8008L29.9368 24.33L33.5208 20.2H32.0368L27.0948 25.758V20.2H25.8768V30Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg fill="none" id="n1_ok" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M25.2125 25.1C25.2125 22.216 23.2945 20.116 20.5365 20.116C17.7785 20.116 15.8605 22.216 15.8605 25.1C15.8605 27.984 17.7785 30.084 20.5365 30.084C23.2945 30.084 25.2125 27.984 25.2125 25.1ZM17.1065 25.1C17.1065 22.846 18.4925 21.236 20.5365 21.236C22.5805 21.236 23.9665 22.846 23.9665 25.1C23.9665 27.354 22.5805 28.964 20.5365 28.964C18.4925 28.964 17.1065 27.354 17.1065 25.1ZM26.7518 30H27.9698V27.452L29.9158 25.254L33.2198 30H34.6758L30.8118 24.33L34.3958 20.2H32.9118L27.9698 25.758V20.2H26.7518V30Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg fill="none" id="n1_tw" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M14.4792 21.32H17.6572V30H18.8752V21.32H22.0532V20.2H14.4792V21.32ZM25.332 30H26.788L29.014 22.23L31.254 30H32.71L35.58 20.2H34.32L32.01 28.432L29.686 20.2H28.454L26.046 28.432L23.75 20.2H22.476L25.332 30Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg height="64px" id="n1_infinity" preserveaspectratio="xMidYMid" style="display:block;width:0;height:0" viewbox="0 0 100 100" width="64px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#    <path d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z" fill="none" stroke="#ffffff" stroke-dasharray="146.25568908691406 110.33323913574219" stroke-linecap="round" stroke-width="5" style="transform:scale(0.8);transform-origin:50px 50px">
#     <animate attributename="stroke-dashoffset" dur="1.3157894736842106s" keytimes="0;1" repeatcount="indefinite" values="0;256.58892822265625">
#     </animate>
#    </path>
#   </svg>
#   <svg fill="none" id="n1_cross" style="display:block;width:0;height:0" viewbox="0 0 14 14" xmlns="http://www.w3.org/2000/svg">
#    <path d="M1.00146 1L13.0015 13" stroke="#F9F9F9">
#    </path>
#    <path d="M13 1L1 13" stroke="#F9F9F9">
#    </path>
#   </svg>
#   <svg id="n1_link_arrow" style="display:block;width:0;height:0" viewbox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
#    <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z" fill="currentColor">
#    </path>
#   </svg>
#   <svg id="n1_big_star" style="display:block;width:0;height:0;" viewbox="0 0 61 61" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" clip-rule="evenodd" d="M3 29.7729H29.0656L10.6345 11.3418L11.3416 10.6347L29.7728 29.0658V3H30.7728V29.0658L49.2039 10.6347L49.911 11.3418L31.4799 29.7729H57.5455V30.7729H31.4799L49.9111 49.2042L49.204 49.9113L30.7728 31.4801V57.5455H29.7728V31.4801L11.3415 49.9113L10.6344 49.2042L29.0656 30.7729H3V29.7729Z" fill-rule="evenodd">
#    </path>
#    <path class="fill-current" d="M29.0656 29.7729V32.2729H35.1012L30.8334 28.0052L29.0656 29.7729ZM3 29.7729V27.2729H0.5V29.7729H3ZM10.6345 11.3418L8.86676 9.57407L7.099 11.3418L8.86676 13.1096L10.6345 11.3418ZM11.3416 10.6347L13.1094 8.86696L11.3416 7.09919L9.57387 8.86696L11.3416 10.6347ZM29.7728 29.0658L28.005 30.8336L32.2728 35.1014V29.0658H29.7728ZM29.7728 3V0.5H27.2728V3H29.7728ZM30.7728 3H33.2728V0.5H30.7728V3ZM30.7728 29.0658H28.2728V35.1014L32.5405 30.8336L30.7728 29.0658ZM49.2039 10.6347L50.9716 8.86696L49.2039 7.09919L47.4361 8.86696L49.2039 10.6347ZM49.911 11.3418L51.6787 13.1096L53.4465 11.3418L51.6787 9.57407L49.911 11.3418ZM31.4799 29.7729L29.7121 28.0052L25.4443 32.2729H31.4799V29.7729ZM57.5455 29.7729H60.0455V27.2729H57.5455V29.7729ZM57.5455 30.7729V33.2729H60.0455V30.7729H57.5455ZM31.4799 30.7729V28.2729H25.4443L29.7121 32.5407L31.4799 30.7729ZM49.9111 49.2042L51.6789 50.972L53.4466 49.2042L51.6789 47.4364L49.9111 49.2042ZM49.204 49.9113L47.4362 51.6791L49.204 53.4468L50.9718 51.6791L49.204 49.9113ZM30.7728 31.4801L32.5405 29.7123L28.2728 25.4445V31.4801H30.7728ZM30.7728 57.5455V60.0455H33.2728V57.5455H30.7728ZM29.7728 57.5455H27.2728V60.0455H29.7728V57.5455ZM29.7728 31.4801H32.2728V25.4445L28.005 29.7123L29.7728 31.4801ZM11.3415 49.9113L9.57374 51.6791L11.3415 53.4468L13.1093 51.6791L11.3415 49.9113ZM10.6344 49.2042L8.86664 47.4364L7.09887 49.2042L8.86664 50.972L10.6344 49.2042ZM29.0656 30.7729L30.8334 32.5407L35.1012 28.2729H29.0656V30.7729ZM3 30.7729H0.5V33.2729H3V30.7729ZM29.0656 27.2729H3V32.2729H29.0656V27.2729ZM8.86676 13.1096L27.2979 31.5407L30.8334 28.0052L12.4023 9.57407L8.86676 13.1096ZM9.57387 8.86696L8.86676 9.57407L12.4023 13.1096L13.1094 12.4025L9.57387 8.86696ZM31.5405 27.2981L13.1094 8.86696L9.57387 12.4025L28.005 30.8336L31.5405 27.2981ZM27.2728 3V29.0658H32.2728V3H27.2728ZM30.7728 0.5H29.7728V5.5H30.7728V0.5ZM33.2728 29.0658V3H28.2728V29.0658H33.2728ZM32.5405 30.8336L50.9716 12.4025L47.4361 8.86696L29.005 27.2981L32.5405 30.8336ZM47.4361 12.4025L48.1432 13.1096L51.6787 9.57407L50.9716 8.86696L47.4361 12.4025ZM48.1432 9.57407L29.7121 28.0052L33.2476 31.5407L51.6787 13.1096L48.1432 9.57407ZM57.5455 27.2729H31.4799V32.2729H57.5455V27.2729ZM60.0455 30.7729V29.7729H55.0455V30.7729H60.0455ZM31.4799 33.2729H57.5455V28.2729H31.4799V33.2729ZM51.6789 47.4364L33.2476 29.0052L29.7121 32.5407L48.1433 50.972L51.6789 47.4364ZM50.9718 51.6791L51.6789 50.972L48.1433 47.4364L47.4362 48.1435L50.9718 51.6791ZM29.005 33.2478L47.4362 51.6791L50.9718 48.1435L32.5405 29.7123L29.005 33.2478ZM33.2728 57.5455V31.4801H28.2728V57.5455H33.2728ZM29.7728 60.0455H30.7728V55.0455H29.7728V60.0455ZM27.2728 31.4801V57.5455H32.2728V31.4801H27.2728ZM28.005 29.7123L9.57374 48.1435L13.1093 51.6791L31.5405 33.2478L28.005 29.7123ZM13.1093 48.1435L12.4022 47.4364L8.86664 50.972L9.57374 51.6791L13.1093 48.1435ZM12.4022 50.972L30.8334 32.5407L27.2979 29.0052L8.86664 47.4364L12.4022 50.972ZM3 33.2729H29.0656V28.2729H3V33.2729ZM0.5 29.7729V30.7729H5.5V29.7729H0.5Z">
#    </path>
#   </svg>
#   <svg class="stroke-current" fill="none" id="n1_circle_arrow" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <rect height="29" rx="14.5" transform="rotate(-180 29.5 29.5)" width="29" x="29.5" y="29.5">
#    </rect>
#    <path d="M9.33985 14.7014L14.6198 19.9414L15.2598 19.3014L11.1198 15.1614L20.3398 15.1614L20.3398 14.2214L11.1198 14.2214L15.2598 10.0814L14.6198 9.44141L9.33985 14.7014Z">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_circle_arrow_solid" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <mask id="path-1-inside-1_2694_77554">
#     <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill-rule="evenodd">
#     </path>
#    </mask>
#    <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill="#fff" fill-rule="evenodd">
#    </path>
#    <path d="M20.6592 15.3001L21.3649 16.0085L22.0774 15.2987L21.3636 14.5903L20.6592 15.3001ZM15.3792 10.0601L16.0836 9.35027L15.3765 8.64853L14.6721 9.35295L15.3792 10.0601ZM15.3792 20.5601L14.6721 21.2672L15.3778 21.9729L16.0849 21.2685L15.3792 20.5601ZM14.7392 19.9201L14.0321 19.213L13.325 19.9201L14.0321 20.6272L14.7392 19.9201ZM18.8792 15.7801L19.5863 16.4872L21.2934 14.7801H18.8792V15.7801ZM9.65918 15.7801H8.65918V16.7801H9.65918V15.7801ZM9.65918 14.8401V13.8401H8.65918V14.8401H9.65918ZM18.8792 14.8401V15.8401H21.2934L19.5863 14.133L18.8792 14.8401ZM14.7392 10.7001L14.0321 9.99295L13.325 10.7001L14.0321 11.4072L14.7392 10.7001ZM1 15C1 7.26801 7.26801 1 15 1V-1C6.16344 -1 -1 6.16344 -1 15H1ZM15 29C7.26801 29 1 22.732 1 15H-1C-1 23.8366 6.16344 31 15 31V29ZM29 15C29 22.732 22.732 29 15 29V31C23.8366 31 31 23.8366 31 15H29ZM15 1C22.732 1 29 7.26801 29 15H31C31 6.16344 23.8366 -1 15 -1V1ZM21.3636 14.5903L16.0836 9.35027L14.6748 10.7698L19.9548 16.0098L21.3636 14.5903ZM16.0849 21.2685L21.3649 16.0085L19.9534 14.5916L14.6734 19.8516L16.0849 21.2685ZM14.0321 20.6272L14.6721 21.2672L16.0863 19.853L15.4463 19.213L14.0321 20.6272ZM18.1721 15.073L14.0321 19.213L15.4463 20.6272L19.5863 16.4872L18.1721 15.073ZM9.65918 16.7801H18.8792V14.7801H9.65918V16.7801ZM8.65918 14.8401V15.7801H10.6592V14.8401H8.65918ZM18.8792 13.8401H9.65918V15.8401H18.8792V13.8401ZM14.0321 11.4072L18.1721 15.5472L19.5863 14.133L15.4463 9.99295L14.0321 11.4072ZM14.6721 9.35295L14.0321 9.99295L15.4463 11.4072L16.0863 10.7672L14.6721 9.35295Z" fill="#fff" mask="url(#path-1-inside-1_2694_77554)">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_play" style="display:block;width:0;height:0;" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#    <path class="stroke-current" d="M18 35V15L36 25L18 35Z">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_pupa" style="display:block;width:0;height:0;" viewbox="0 0 24 23" xmlns="http://www.w3.org/2000/svg">
#    <path clip-rule="evenodd" d="M17 8.80329C17 13.0922 13.4392 16.6066 9 16.6066C4.56077 16.6066 1 13.0922 1 8.80329C1 4.51437 4.56077 1 9 1C13.4392 1 17 4.51437 17 8.80329ZM14.9967 15.3678C13.4049 16.7601 11.3035 17.6066 9 17.6066C4.02944 17.6066 0 13.6652 0 8.80329C0 3.94137 4.02944 0 9 0C13.9706 0 18 3.94137 18 8.80329C18 11.0562 17.1348 13.1114 15.7118 14.6684L23.3531 22.1427C23.5505 22.3358 23.554 22.6524 23.3609 22.8498C23.1678 23.0472 22.8513 23.0507 22.6539 22.8576L14.9967 15.3678Z" fill="#32363A" fill-rule="evenodd">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_burger" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <line stroke="#32363A" x2="30" y1="6.5" y2="6.5">
#    </line>
#    <line stroke="#32363A" x2="30" y1="23.5" y2="23.5">
#    </line>
#    <line stroke="#32363A" x2="30" y1="15" y2="15">
#    </line>
#   </svg>
#   <svg fill="none" id="n1_cross_menu" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <path d="M4 4L26 26" stroke="#32363A">
#    </path>
#    <path d="M26 4L4 26" stroke="#32363A">
#    </path>
#   </svg>
#   <svg id="n1_check" style="display:block;width:0;height:0;fill:currentColor" version="1.1" viewbox="0 0 752 752" xmlns="http://www.w3.org/2000/svg">
#    <path d="m183.6 357.87-22.184 22.168v0.003907c-3.2969 3.293-3.2969 8.6367 0 11.934l133.29 133.28v0.003907c3.7305 3.7266 8.7891 5.8242 14.066 5.8242 5.2734 0 10.332-2.0977 14.062-5.8242l267.76-267.76c1.582-1.582 2.4727-3.7305 2.4727-5.9688 0-2.2383-0.89062-4.3867-2.4727-5.9688l-22.156-22.168c-1.582-1.5898-3.7344-2.4805-5.9727-2.4805-2.2422 0-4.3945 0.89062-5.9766 2.4805l-244.31 244.3c-1.8828 1.8789-4.9336 1.8789-6.8164 0l-109.84-109.83c-3.293-3.2852-8.625-3.2852-11.918 0z">
#    </path>
#   </svg>
#   <script src="/front-build/js/app.js?v=2">
#   </script>
#   <!-- Yandex.Metrika counter 2-->
#   <script type="text/javascript">
#    (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(88946384, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true
# });
#
#
# ym(29654565, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash:true,
# 	ecommerce:"dataLayer"
# });
#   </script>
#   <noscript>
#    <div>
#     <img alt="" src="https://mc.yandex.ru/watch/88946384" style="position:absolute; left:-9999px;"/>
#     <img alt="" src="https://mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;"/>
#    </div>
#   </noscript>
#   <!-- /Yandex.Metrika counter -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-61773772-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-61773772-1');
#   </script>
#   <script>
#    if ('serviceWorker' in navigator) {
# 	window.addEventListener('load', () => {
# 		navigator.serviceWorker.register('/front-service-worker.js').then(reg => {
# 			// sometime later…
# 			reg.update()
# 		})
# 	})
# }
#   </script>
#  </body>
# </html>

# %% [markdown]
# В такой выдаче ориентироваться гораздо удобнее (но при желании, то же можно увидеть в браузере, на большом экране).

# %% [markdown]
# Чтобы сгрузить все новости с главной страницы сайта, нужно собрать все ссылки на страницы с этими новостями. Ссылки в html-файле всегда заключены в тэг `<a></a>` и имеют атрибут `href`. Посмотрим на кусочки кода, соответствующие всем ссылкам на главной странице сайта:

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# /search
# https://offline.nplus1.ru/
# https://nplus.pro/
# https://nplus1.ru/about
# https://nplus1.ru/difficult
# https://nplus1.ru/adv
# https://nplus1.ru/blog/2022/04/01/samotek
# /search/empty/869
# /search/empty/874
# /search/empty/880
# /search/empty/768
# /search/empty/890
# /search/empty/871
# /search/empty/876
# /search/empty/775
# /search/empty/767
# /search/empty/771
# /search/empty/772
# /search/empty/778
# /search/empty/917
# /search/empty/918
# /search/empty/824
# https://t.me/nplusone
# https://vk.com/nplusone
# https://ok.ru/nplus1
# https://twitter.com/nplusodin
# https://nplus1.ru/about
# https://nplus1.ru/difficult
# https://nplus1.ru/adv
# https://nplus1.ru/news/2015/09/21/editor-thy-name
# /search/empty/869
# /search/empty/874
# /search/empty/880
# /search/empty/768
# /search/empty/890
# /search/empty/871
# /search/empty/876
# /search/empty/775
# /search/empty/767
# /search/empty/771
# /search/empty/772
# /search/empty/778
# /search/empty/917
# /search/empty/918
# /search/empty/824
# https://offline.nplus1.ru/
# https://nplus.pro/
# https://t.me/nplusone
# https://vk.com/nplusone
# https://ok.ru/nplus1
# https://twitter.com/nplusodin
# https://nplus1.ru/material/2022/10/31/robotaxi-arriving
# /search/empty/812
# /search/empty/887
# /material/difficulty/3
# https://nplus1.ru/blog/2022/10/28/black-raven
# /search/empty/817
# /search/empty/877
# /material/difficulty/3
# https://nplus1.ru/blog/2022/10/28/zolgensma
# /search/empty/873
# /material/difficulty/4
# https://nplus1.ru/news/2022/10/31/bombus-terrestris
# /search/empty/874
# /material/difficulty/5
# /news/2022/11/01
# /search/empty/817
# /material/difficulty/2
# https://nplus1.ru/news/2022/11/01/nudes
# /news/2022/11/01
# /search/empty/869
# /material/difficulty/3
# https://nplus1.ru/news/2022/11/01/why-cats-have-nine-lives
# /news/2022/11/01
# /search/empty/874
# /material/difficulty/3
# https://nplus1.ru/news/2022/11/01/otus-bikegila
# /news/2022/11/01
# /search/empty/877
# /material/difficulty/3
# https://nplus1.ru/news/2022/11/01/family-in-jar
# /news/2022/11/01
# /search/empty/873
# /material/difficulty/2
# https://nplus1.ru/news/2022/11/01/mali-malaria-mab
# /news/2022/10/31
# /search/empty/880
# /material/difficulty/3
# https://nplus1.ru/news/2022/10/31/echo-hubble
# /news/2022/10/31
# /search/empty/874
# /material/difficulty/5
# https://nplus1.ru/news/2022/10/31/bombus-terrestris
# /news/2022/10/31
# /search/empty/890
# /material/difficulty/5
# https://nplus1.ru/news/2022/10/31/marking-model
# /news/2022/10/31
# /search/empty/871
# /material/difficulty/1
# https://nplus1.ru/news/2022/10/31/mars-samples
# /news/2022/10/31
# /search/empty/880
# /material/difficulty/4
# https://nplus1.ru/news/2022/10/31/hubble-rocky-atmosphere
# /news/2022/10/31
# /search/empty/885
# /material/difficulty/4
# https://nplus1.ru/news/2022/10/31/retina-moving
# /news/2022/10/31
# /search/empty/876
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/31/ephesos
# https://nplus1.ru/material/2022/10/26/wildlife-photographer-of-the-year-2022-the-winning-images
# /material/2022/10/26
# /search/empty/874
# /search/empty/872
# /material/difficulty/1
# https://nplus1.ru/material/2022/10/26/wildlife-photographer-of-the-year-2022-the-winning-images
# https://nplus1.ru/blog/2022/10/26/a-planet-of-viruses
# /blog/2022/10/26
# /search/empty/885
# /material/difficulty/1
# https://nplus1.ru/blog/2022/10/26/a-planet-of-viruses
# /news/2022/10/31
# /search/empty/869
# /material/difficulty/4
# https://nplus1.ru/news/2022/10/31/sheep-collective-motion
# /news/2022/10/31
# /search/empty/871
# /material/difficulty/1
# https://nplus1.ru/news/2022/10/31/mengtian-launch
# https://nplus1.ru/material/2022/10/19/17-altay-neanderthals
# /material/2022/10/19
# /search/empty/877
# /material/difficulty/4
# https://nplus1.ru/material/2022/10/19/17-altay-neanderthals
# https://nplus1.ru/material/2022/10/19/why-theranos-failed
# /search/empty/885
# /material/difficulty/6
# https://nplus1.ru/material/2022/10/19/why-theranos-failed
# /blog/2022/10/20
# /search/empty/817
# /material/difficulty/1
# /author/nlo
# https://nplus1.ru/blog/2022/10/20/state-laughter
# /news/2022/10/31
# /search/empty/876
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/31/iron-age-woman
# /news/2022/10/29
# /search/empty/880
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/29/sun-video
# /news/2022/10/29
# /search/empty/871
# /material/difficulty/1
# https://nplus1.ru/news/2022/10/29/psyche-2023
# https://nplus1.ru/material/2022/10/18/lifelong-learning
# /material/2022/10/18
# /search/empty/812
# /material/difficulty/4
# https://nplus1.ru/material/2022/10/18/lifelong-learning
# /news/2022/10/29
# /search/empty/869
# /material/difficulty/6
# https://nplus1.ru/news/2022/10/29/all-at-once
# /news/2022/10/29
# /search/empty/880
# /material/difficulty/4
# https://nplus1.ru/news/2022/10/29/marsquake-is-bolide
# https://nplus1.ru/material/2022/10/14/better-call-a-doctor
# /material/2022/10/14
# /search/empty/873
# /material/difficulty/3
# https://nplus1.ru/material/2022/10/14/better-call-a-doctor
# https://nplus1.ru/material/2022/10/13/EVALI-explained
# /search/empty/873
# /material/difficulty/4
# https://nplus1.ru/material/2022/10/13/EVALI-explained
# /blog/2022/10/17
# /search/empty/817
# /material/difficulty/1
# /author/alpina-non-fiksn
# https://nplus1.ru/blog/2022/10/17/headstrong
# /news/2022/10/29
# /search/empty/869
# /material/difficulty/5
# https://nplus1.ru/news/2022/10/29/Beer-and-Cola
# /news/2022/10/29
# /search/empty/882
# /material/difficulty/3
# https://nplus1.ru/news/2022/10/29/nightmares-therapy
# /news/2022/10/29
# /search/empty/870
# /material/difficulty/4
# https://nplus1.ru/news/2022/10/29/amorphous-polymer-conductor
# https://nplus1.ru/material/2022/10/10/aerosols
# /material/2022/10/10
# /search/empty/812
# /material/difficulty/6
# https://nplus1.ru/material/2022/10/10/aerosols
# /news/2022/10/29
# /search/empty/876
# /material/difficulty/1
# https://nplus1.ru/news/2022/10/29/prison-camp
# /news/2022/10/28
# /search/empty/881
# /material/difficulty/1
# https://nplus1.ru/news/2022/10/28/mouse
# https://nplus1.ru/material/2022/10/10/computer-vision
# /material/2022/10/10
# /search/empty/812
# /material/difficulty/3
# https://nplus1.ru/material/2022/10/10/computer-vision
# https://nplus1.ru/material/2022/10/06/chemistry-nobel-2022
# /search/empty/870
# /search/empty/785
# /material/difficulty/7
# https://nplus1.ru/material/2022/10/06/chemistry-nobel-2022
# /blog/2022/10/14
# /search/empty/875
# /material/difficulty/2
# /author/nkulbaka
# https://nplus1.ru/blog/2022/10/14/ti-popal-popadanets
# /news/2022/10/28
# /search/empty/874
# /material/difficulty/1
# https://nplus1.ru/news/2022/10/28/daubentonia-madagascariensis
# /news/2022/10/28
# /search/empty/871
# /material/difficulty/1
# https://nplus1.ru/news/2022/10/28/seismometer-for-moon
# /news/2022/10/28
# /search/empty/869
# /material/difficulty/6
# https://nplus1.ru/news/2022/10/28/Lorentz-transformation-examine
# https://nplus1.ru/material/2022/10/05/how-to-lungs
# /material/2022/10/05
# /search/empty/812
# /material/difficulty/4
# https://nplus1.ru/material/2022/10/05/how-to-lungs
# /news/2022/10/28
# /search/empty/877
# /material/difficulty/3
# https://nplus1.ru/news/2022/10/28/alan-heritage
# /news/2022/10/28
# /search/empty/880
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/28/europe-sounds
# https://nplus1.ru/material/2022/10/04/physics-nobel-2022
# /material/2022/10/04
# /search/empty/869
# /material/difficulty/6
# https://nplus1.ru/material/2022/10/04/physics-nobel-2022
# https://nplus1.ru/material/2022/10/03/nobel-physmed-2022
# /search/empty/885
# /search/empty/785
# /material/difficulty/2
# https://nplus1.ru/material/2022/10/03/nobel-physmed-2022
# /blog/2022/10/13
# /search/empty/817
# /material/difficulty/1
# /author/nlo
# https://nplus1.ru/blog/2022/10/13/a-public-empire
# /news/2022/10/28
# /search/empty/880
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/28/sprites-for-all
# /news/2022/10/28
# /search/empty/876
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/28/viking-silver-treasure
# /news/2022/10/28
# /search/empty/874
# /material/difficulty/3
# https://nplus1.ru/news/2022/10/28/talking-with-cats
# https://nplus1.ru/material/2022/09/30/under-pressure
# /material/2022/09/30
# /search/empty/869
# /material/difficulty/7
# https://nplus1.ru/material/2022/09/30/under-pressure
# /news/2022/10/28
# /search/empty/869
# /material/difficulty/6
# https://nplus1.ru/news/2022/10/28/no-traces-of-quantum-gravity
# /news/2022/10/28
# /search/empty/873
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/28/convacel-vaccine
# https://nplus1.ru/material/2022/09/16/ignobel-2022
# /material/2022/09/16
# /search/empty/875
# /material/difficulty/3
# https://nplus1.ru/material/2022/09/16/ignobel-2022
# https://nplus1.ru/material/2022/09/14/birds2022
# /search/empty/874
# /search/empty/772
# /material/difficulty/0
# https://nplus1.ru/material/2022/09/14/birds2022
# /blog/2022/10/11
# /search/empty/898
# /material/difficulty/3
# /author/konstantin-egorov
# https://nplus1.ru/blog/2022/10/11/econ-nobel-2022
# /news/2022/10/27
# /search/empty/875
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/27/3d-city
# /news/2022/10/27
# /search/empty/880
# /material/difficulty/4
# https://nplus1.ru/news/2022/10/27/substellar-and-neptune
# /news/2022/10/27
# /search/empty/876
# /material/difficulty/1
# https://nplus1.ru/news/2022/10/27/mashki-gate
# https://nplus1.ru/material/2022/09/13/dirt
# /material/2022/09/13
# /search/empty/885
# /material/difficulty/6
# https://nplus1.ru/material/2022/09/13/dirt
# /news/2022/10/27
# /search/empty/872
# /material/difficulty/3
# https://nplus1.ru/news/2022/10/27/wmo-greenhouse-gases-2022
# /news/2022/10/27
# /search/empty/874
# /material/difficulty/1
# https://nplus1.ru/news/2022/10/27/skolnik-obessmertil-skalariu
# https://nplus1.ru/material/2022/09/13/seti-drake
# /material/2022/09/13
# /search/empty/880
# /material/difficulty/4
# https://nplus1.ru/material/2022/09/13/seti-drake
# https://nplus1.ru/material/2022/09/08/majoranas-hoax
# /search/empty/869
# /search/empty/788
# /material/difficulty/9
# https://nplus1.ru/material/2022/09/08/majoranas-hoax
# /blog/2022/10/11
# /search/empty/900
# /material/difficulty/3
# /author/yulli-uletova
# https://nplus1.ru/blog/2022/10/11/bosporan-gold
# /news/2022/10/27
# /search/empty/869
# /material/difficulty/4
# https://nplus1.ru/news/2022/10/27/quantum-watch
# /news/2022/10/27
# /search/empty/870
# /material/difficulty/6
# https://nplus1.ru/news/2022/10/27/polyporphirin-magnets
# /news/2022/10/27
# /search/empty/873
# /material/difficulty/3
# https://nplus1.ru/news/2022/10/27/flu-rsv-hybrid
# https://nplus1.ru/material/2022/09/01/WildlifePhotographer2022
# /material/2022/09/01
# /search/empty/874
# /material/difficulty/0
# https://nplus1.ru/material/2022/09/01/WildlifePhotographer2022
# /news/2022/10/27
# /search/empty/876
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/27/viking-age-bowl
# /news/2022/10/26
# /search/empty/874
# /material/difficulty/3
# https://nplus1.ru/news/2022/10/26/facial-neurons-elephants
# https://nplus1.ru/material/2022/08/26/artemis-1
# /material/2022/08/26
# /search/empty/871
# /material/difficulty/4
# https://nplus1.ru/material/2022/08/26/artemis-1
# https://nplus1.ru/material/2022/08/23/x-ray-forgery
# /search/empty/870
# /search/empty/778
# /material/difficulty/6
# https://nplus1.ru/material/2022/08/23/x-ray-forgery
# /blog/2022/10/10
# /search/empty/906
# /material/difficulty/1
# /author/alpina-non-fiksn
# https://nplus1.ru/blog/2022/10/10/eine-kurze-weltgeschichte
# /news/2022/10/26
# /search/empty/874
# /material/difficulty/1
# https://nplus1.ru/news/2022/10/26/234684
# /news/2022/10/26
# /search/empty/877
# /material/difficulty/3
# https://nplus1.ru/news/2022/10/26/child-mummy
# /news/2022/10/26
# /search/empty/873
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/26/lean-body-mass
# https://nplus1.ru/material/2022/08/23/there-is-a-task-podcast
# /material/2022/08/23
# /search/empty/812
# /material/difficulty/4
# https://nplus1.ru/material/2022/08/23/there-is-a-task-podcast
# /news/2022/10/19
# /search/empty/876
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/19/stone-statue
# /news/2022/10/28
# /search/empty/877
# /material/difficulty/3
# https://nplus1.ru/news/2022/10/28/alan-heritage
# /news/2022/10/26
# /search/empty/873
# /material/difficulty/1
# https://nplus1.ru/news/2022/10/26/turmeric-damages-liver
# /news/2022/10/19
# /search/empty/876
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/19/golden-belt
# /news/2022/10/22
# /search/empty/876
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/22/rock-art
# /news/2022/10/17
# /search/empty/874
# /material/difficulty/1
# https://nplus1.ru/news/2022/10/17/mola-alexandrini
# /news/2022/10/04
# /search/empty/874
# /material/difficulty/1
# https://nplus1.ru/news/2022/10/04/cows
# /news/2022/10/24
# /search/empty/876
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/24/hoard-from-poland
# /news/2022/10/03
# /search/empty/876
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/03/saka-burial
# /news/2022/10/22
# /search/empty/880
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/22/2022-uq-1
# /material/2022/10/13
# /search/empty/873
# /material/difficulty/4
# https://nplus1.ru/material/2022/10/13/EVALI-explained
# /news/2022/10/14
# /search/empty/876
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/14/gorn
# /news/2022/10/15
# /search/empty/876
# /material/difficulty/3
# https://nplus1.ru/news/2022/10/15/scythians
# /news/2022/10/21
# /search/empty/869
# /material/difficulty/8
# https://nplus1.ru/news/2022/10/21/proton-anomaly
# /news/2022/10/17
# /search/empty/874
# /material/difficulty/4
# https://nplus1.ru/news/2022/10/17/mental-number-line
# /news/2022/10/20
# /search/empty/883
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/20/exterminaaate
# /news/2022/10/12
# /search/empty/876
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/12/phanagoria
# /material/2022/10/18
# /search/empty/812
# /material/difficulty/4
# https://nplus1.ru/material/2022/10/18/lifelong-learning
# /news/2022/10/28
# /search/empty/876
# /material/difficulty/2
# https://nplus1.ru/news/2022/10/28/viking-silver-treasure
# /news/2022/10/11
# /search/empty/876
# /material/difficulty/3
# https://nplus1.ru/news/2022/10/11/xiaoma-caves
# /material/2022/10/20
# /search/empty/873
# /search/empty/812
# /material/difficulty/3
# https://nplus1.ru/material/2022/10/20/AI-alertness
# /blog/2022/10/26
# /search/empty/885
# /material/difficulty/4
# https://nplus1.ru/blog/2022/10/26/gof
# https://nplus1.ru/news/2022/10/12/smiling-electrons
# https://nplus1.ru/news/2022/10/13/vliyanie-elektronnyx-korrelyacii-v-kristallax-vyyavili-s-attosekundnoi-tocnostyu
# https://nplus1.ru/news/2022/10/14/charge-transfer-photocatalysis
# https://nplus1.ru/news/2022/10/14/polyarizuemost-protona
# https://nplus1.ru/news/2022/10/19/Casimir-i-triode
# https://nplus1.ru/material/2022/10/19/why-theranos-failed
# https://nplus1.ru/news/2022/10/20/zvukovoi-impuls-naucili-perenosit-elektrony
# https://nplus1.ru/news/2022/10/21/proton-anomaly
# https://nplus1.ru/news/2022/10/24/entanglement-enhanced-interferometry
# https://nplus1.ru/news/2022/10/26/fiziki-sozdali-castotnoe-zerkalo
# https://nplus1.ru/news/2022/10/27/polyporphirin-magnets
# https://nplus1.ru/news/2022/10/28/no-traces-of-quantum-gravity
# https://nplus1.ru/news/2022/10/28/Lorentz-transformation-examine
# https://nplus1.ru/news/2022/10/29/Beer-and-Cola
# https://nplus1.ru/news/2022/10/29/all-at-once
# https://nplus1.ru/about
# https://nplus1.ru/difficult
# https://nplus1.ru/adv
# https://nplus1.ru/blog/2022/04/01/samotek
# mailto:kirill@nplus1.ru
# mailto:info@nplus1.ru
# /personal-data-policy
# https://t.me/nplusone
# https://vk.com/nplusone
# https://ok.ru/nplus1
# https://twitter.com/nplusodin

# %% [markdown]
# Ссылок много. Но нам нужны только новости – ссылки, которые начинаются со слова `/news`. Добавим условие: будем выбирать только те ссылки, в которых есть `/news`. Создадим пустой список `urls` и будем добавлять в него только ссылки, которые удовлетворяют этому условию.

# %%
urls = []

for link in soup.find_all('a'):
    if '/news' in link.get('href'):
        if 'https://' in link.get('href'):
            urls.append(link.get('href'))
urls
# Out:
# ['https://nplus1.ru/news/2015/09/21/editor-thy-name',
#  'https://nplus1.ru/news/2022/10/31/bombus-terrestris',
#  'https://nplus1.ru/news/2022/11/01/nudes',
#  'https://nplus1.ru/news/2022/11/01/why-cats-have-nine-lives',
#  'https://nplus1.ru/news/2022/11/01/otus-bikegila',
#  'https://nplus1.ru/news/2022/11/01/family-in-jar',
#  'https://nplus1.ru/news/2022/11/01/mali-malaria-mab',
#  'https://nplus1.ru/news/2022/10/31/echo-hubble',
#  'https://nplus1.ru/news/2022/10/31/bombus-terrestris',
#  'https://nplus1.ru/news/2022/10/31/marking-model',
#  'https://nplus1.ru/news/2022/10/31/mars-samples',
#  'https://nplus1.ru/news/2022/10/31/hubble-rocky-atmosphere',
#  'https://nplus1.ru/news/2022/10/31/retina-moving',
#  'https://nplus1.ru/news/2022/10/31/ephesos',
#  'https://nplus1.ru/news/2022/10/31/sheep-collective-motion',
#  'https://nplus1.ru/news/2022/10/31/mengtian-launch',
#  'https://nplus1.ru/news/2022/10/31/iron-age-woman',
#  'https://nplus1.ru/news/2022/10/29/sun-video',
#  'https://nplus1.ru/news/2022/10/29/psyche-2023',
#  'https://nplus1.ru/news/2022/10/29/all-at-once',
#  'https://nplus1.ru/news/2022/10/29/marsquake-is-bolide',
#  'https://nplus1.ru/news/2022/10/29/Beer-and-Cola',
#  'https://nplus1.ru/news/2022/10/29/nightmares-therapy',
#  'https://nplus1.ru/news/2022/10/29/amorphous-polymer-conductor',
#  'https://nplus1.ru/news/2022/10/29/prison-camp',
#  'https://nplus1.ru/news/2022/10/28/mouse',
#  'https://nplus1.ru/news/2022/10/28/daubentonia-madagascariensis',
#  'https://nplus1.ru/news/2022/10/28/seismometer-for-moon',
#  'https://nplus1.ru/news/2022/10/28/Lorentz-transformation-examine',
#  'https://nplus1.ru/news/2022/10/28/alan-heritage',
#  'https://nplus1.ru/news/2022/10/28/europe-sounds',
#  'https://nplus1.ru/news/2022/10/28/sprites-for-all',
#  'https://nplus1.ru/news/2022/10/28/viking-silver-treasure',
#  'https://nplus1.ru/news/2022/10/28/talking-with-cats',
#  'https://nplus1.ru/news/2022/10/28/no-traces-of-quantum-gravity',
#  'https://nplus1.ru/news/2022/10/28/convacel-vaccine',
#  'https://nplus1.ru/news/2022/10/27/3d-city',
#  'https://nplus1.ru/news/2022/10/27/substellar-and-neptune',
#  'https://nplus1.ru/news/2022/10/27/mashki-gate',
#  'https://nplus1.ru/news/2022/10/27/wmo-greenhouse-gases-2022',
#  'https://nplus1.ru/news/2022/10/27/skolnik-obessmertil-skalariu',
#  'https://nplus1.ru/news/2022/10/27/quantum-watch',
#  'https://nplus1.ru/news/2022/10/27/polyporphirin-magnets',
#  'https://nplus1.ru/news/2022/10/27/flu-rsv-hybrid',
#  'https://nplus1.ru/news/2022/10/27/viking-age-bowl',
#  'https://nplus1.ru/news/2022/10/26/facial-neurons-elephants',
#  'https://nplus1.ru/news/2022/10/26/234684',
#  'https://nplus1.ru/news/2022/10/26/child-mummy',
#  'https://nplus1.ru/news/2022/10/26/lean-body-mass',
#  'https://nplus1.ru/news/2022/10/19/stone-statue',
#  'https://nplus1.ru/news/2022/10/28/alan-heritage',
#  'https://nplus1.ru/news/2022/10/26/turmeric-damages-liver',
#  'https://nplus1.ru/news/2022/10/19/golden-belt',
#  'https://nplus1.ru/news/2022/10/22/rock-art',
#  'https://nplus1.ru/news/2022/10/17/mola-alexandrini',
#  'https://nplus1.ru/news/2022/10/04/cows',
#  'https://nplus1.ru/news/2022/10/24/hoard-from-poland',
#  'https://nplus1.ru/news/2022/10/03/saka-burial',
#  'https://nplus1.ru/news/2022/10/22/2022-uq-1',
#  'https://nplus1.ru/news/2022/10/14/gorn',
#  'https://nplus1.ru/news/2022/10/15/scythians',
#  'https://nplus1.ru/news/2022/10/21/proton-anomaly',
#  'https://nplus1.ru/news/2022/10/17/mental-number-line',
#  'https://nplus1.ru/news/2022/10/20/exterminaaate',
#  'https://nplus1.ru/news/2022/10/12/phanagoria',
#  'https://nplus1.ru/news/2022/10/28/viking-silver-treasure',
#  'https://nplus1.ru/news/2022/10/11/xiaoma-caves',
#  'https://nplus1.ru/news/2022/10/12/smiling-electrons',
#  'https://nplus1.ru/news/2022/10/13/vliyanie-elektronnyx-korrelyacii-v-kristallax-vyyavili-s-attosekundnoi-tocnostyu',
#  'https://nplus1.ru/news/2022/10/14/charge-transfer-photocatalysis',
#  'https://nplus1.ru/news/2022/10/14/polyarizuemost-protona',
#  'https://nplus1.ru/news/2022/10/19/Casimir-i-triode',
#  'https://nplus1.ru/news/2022/10/20/zvukovoi-impuls-naucili-perenosit-elektrony',
#  'https://nplus1.ru/news/2022/10/21/proton-anomaly',
#  'https://nplus1.ru/news/2022/10/24/entanglement-enhanced-interferometry',
#  'https://nplus1.ru/news/2022/10/26/fiziki-sozdali-castotnoe-zerkalo',
#  'https://nplus1.ru/news/2022/10/27/polyporphirin-magnets',
#  'https://nplus1.ru/news/2022/10/28/no-traces-of-quantum-gravity',
#  'https://nplus1.ru/news/2022/10/28/Lorentz-transformation-examine',
#  'https://nplus1.ru/news/2022/10/29/Beer-and-Cola',
#  'https://nplus1.ru/news/2022/10/29/all-at-once']

# %% [markdown]
# Теперь наша задача сводится к следующему: изучить одну страницу с новостью, научиться из нее вытаскивать текст и всю необходимую информацию, а потом применить весь набор действий к каждой ссылке из `full_urls` в цикле. Посмотрим на новость с индексом 1, у вас может быть другая, новости обновляются.

# %%
url0 = urls[15]

page0 = requests.get(url0)
soup0 = BeautifulSoup(page0.text, 'lxml')

# %% [markdown]
# В коде каждой страницы с новостью есть часть с мета-информацией: датой, именем автора и проч. Такая информация окружена тэгом `<meta></meta>`. Посмотрим:

# %%
soup0.find_all('meta')
# Out:
# [<meta charset="utf-8"/>,
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>,
#  <meta content="8c90b02c84ac3b72" name="yandex-verification"/>,
#  <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>,
#  <meta content="N + 1: научные статьи, новости, открытия" property="og:site_name"/>,
#  <meta content="Китай запустил в космос последний модуль орбитальной станции «Тяньгун»" property="og:title"/>,
#  <meta content="https://app-images.website.yandexcloud.net/711812/635f7d4b5fafc_cover_share.jpg" property="og:image"/>,
#  <meta content="https://nplus1.ru/news/2022/10/31/mengtian-launch" property="og:url"/>,
#  <meta content="Это лабораторный модуль «Мэньтянь»" property="og:description"/>,
#  <meta content="article" property="og:type"/>,
#  <meta content="2022-10-31" itemprop="datePublished"/>,
#  <meta content="2022-10-31" itemprop="datePublished"/>,
#  <meta content="Александр Войтюк" name="mediator_author"/>,
#  <meta content="Александр Войтюк" name="author"/>,
#  <meta content="" name="copyright"/>,
#  <meta content="summary_large_image" name="twitter:card"/>,
#  <meta content="@nplusodin" name="twitter:site"/>,
#  <meta content="Китай запустил в космос последний модуль орбитальной станции «Тяньгун»" name="twitter:title"/>,
#  <meta content="Это лабораторный модуль «Мэньтянь»" name="twitter:description"/>,
#  <meta content="https://app-images.website.yandexcloud.net/711812/635f7d4b5fafc_cover_share.jpg" name="twitter:image"/>]

# %% [markdown]
# Из этого списка нам нужны части с именем автора, датой, заголовком и кратким описанием. Воспользуемся поиском по атрибуту `name`. Передадим функции `find_all()` в качестве аргумента словарь с названием и значением атрибута:

# %%
soup0.find_all('meta', {'name' : 'author'}) # например, автор
# Out:
# [<meta content="Михаил Подрезов" name="author"/>]

# %% [markdown]
# Теперь выберем единственный элемент полученного списка (с индексом 0):

# %%
soup0.find_all('meta', {'name' : 'author'})[0]
# Out:
# <meta content="Михаил Подрезов" name="author"/>

# %% [markdown]
# Нам нужно вытащить из этого объекта `content` – имя автора. Посмотрим на атрибуты:

# %%
soup0.find_all('meta', {'name' : 'author'})[0].attrs
# Out:
# {'name': 'author', 'content': 'Михаил Подрезов'}

# %% [markdown]
# Как получить отсюда `content`? Очень просто, ведь это словарь! А доставать из словаря значение по ключу мы умеем.

# %%
author = soup0.find_all('meta', {'name' : 'author'})[0].attrs['content']
author
# Out:
# 'Михаил Подрезов'

# %% [markdown]
# Аналогичным образом извлечем дату, заголовок и описание.

# %%
date = soup0.find_all('meta', {'itemprop' : 'datePublished'})[0].attrs['content']
title = soup0.find_all('meta', {'property' : 'og:title'})[0].attrs['content']
description = soup0.find_all('meta', {'property' : 'og:description'})[0].attrs['content']

# %% [markdown]
# Не прошло и двух пар, как мы разобрались со всем :) Теперь осталось совсем чуть-чуть. Написать готовую функцию для всех проделанных нами действий и применить ее в цикле для всех ссылок в списке `full_urls`. Напишем! Аргументом функции будет ссылка на новость, а возвращать она будет текст новости и всю необходимую информацию (дата, автор, сложность и проч.). Скопируем все строки кода выше.

# %%
def GetNews(url0):
    """
    Returns a tuple with url0, date, author, description, title, final_text, rubrics, diff.
    Parameters:
    
    url0 is a link to the news (string)
    """
    page0 = requests.get(url0)
    soup0 = BeautifulSoup(page0.text, 'lxml')
    
    author = soup0.find_all('meta', {'name' : 'author'})[0].attrs['content']
    date = soup0.find_all('meta', {'itemprop' : 'datePublished'})[0].attrs['content']
    title = soup0.find_all('meta', {'property' : 'og:title'})[0].attrs['content']
    description = soup0.find_all('meta', {'property'  : 'og:description'})[0].attrs['content']
 
    
    return url0, date, author, description, title

# %% [markdown]
# Уфф. Осталось применить ее в цикле. Но давайте не будем спешить: импортируем функцию `sleep` для задержки, чтобы на каждой итерации цикла, прежде чем перейти к следующей новости, Python ждал несколько секунд. Во-первых, это нужно, чтобы сайт «не понял», чтобы мы его грабим, да еще автоматически. Во-вторых, с небольшой задержкой всегда есть гарантия, что страница прогрузится (сейчас это пока не очень важно, но особенно актуально будет, когда будем обсуждать встраивание в браузер с Selenium). Приступим.

# %%
from time import sleep

# %%
len(urls)
# Out:
# 81

# %%
news = [] # это будет список из кортежей, в которых будут храниться данные по каждой новости

for link in urls[:50]:
    res = GetNews(link)
    news.append(res)
    sleep(1) # задержка в 3 секунды

# %%
news[0]
# Out:
# ('https://nplus1.ru/news/2015/09/21/editor-thy-name',
#  '2015-09-21',
#  'Андрей Коняев',
#  '',
#  'Мы ищем редакторов: физиков, археологов, медиков')

# %% [markdown]
# Так теперь выглядит первый элемент списка:

# %% [markdown]
# Импортируем `pandas` и создадим датафрейм из списка кортежей:

# %%
import pandas as pd

# %%
df = pd.DataFrame(news)

# %%
df.head(10)

# %% [markdown]
# Переименуем столбцы в базе.

# %%
df.columns = ['link', 'date', 'author', 'desc', 'title', 'text', 'rubric', 'diffc']

# %%
df.head(2)

# %% [markdown]
# Теперь внесем изменения: сделаем столбец `diffc` числовым – типа *float*.

# %%
df['diffc'] = [float(i) for i in df.diffc]

# %% [markdown]
# Теперь сложность представлена в базе как количественный показатель, и описывать ее можно соответствующим образом:

# %%
df.diffc.describe()

# %% [markdown]
# Теперь столбец со сложностью точно числовой. Можем даже построить для него гистограмму.

# %%
# %matplotlib inline
df.diffc.plot.hist()

# %% [markdown]
# Объединим рубрики в *text* в одну строку через запятую:

# %%
df['rubric'] = [','.join(r) for r in df.rubric]

# %% [markdown]
# Давайте почистим текст новостей – уберем оттуда текст, не относящийся к новостям. Найдем лишнее:

# %%
df.text[0]

# %% [markdown]
# Лишний текст находится после фразы 'Нашли опечатку?'. Так давайте будем разбивать строки по этой фразе с помощью метода `.split()` и брать все, что до нее (элемент с индексом 0).

# %%
df['clean_text'] = [t.split('Нашли опечатку?')[0] for t in df.text]

# %% [markdown]
# Осталось только заменить непонятные символы `\xa0` на пробелы:

# %%
df['clean_text'] = [t.replace("\xa0", " ") for t in df.clean_text]

# %%
df.clean_text[0]

# %% [markdown]
# Всё! Сохраняем датафрейм в файл. Для разнообразия сохраним в Excel:

# %%
df.to_excel('nplus-news.xlsx')
