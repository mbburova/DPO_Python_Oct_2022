# %% [markdown]
# # Программирование для всех
#
# *Алла Тамбовцева, НИУ ВШЭ*
#
# ## Парсинг HTML-файлов с помощью `BeautifulSoup`

# %% [markdown]
# Мы уже немного познакомились со структурой html-страниц, теперь попробуем выгрузить информацию из реально существующей страницы, а точнее, с сайта [nplus1.ru](https://nplus1.ru/). Наша задача – выгрузить недавние новости в датафрейм `pandas`, чтобы потом сохранить все в файл Excel.
#
# Для работы нам понадобится модуль `requests` для отправки запросов, для «подключения» к странице и получения ее содержимого в виде строки, и функция `BeautifulSoup` из библиотеки `bs4` для удобного поиска по полученной строке:

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Сохраним ссылку на главную страницу в переменную `main`:

# %%
main = "https://nplus1.ru/"

# %% [markdown]
# Сформируем запрос, отправим его и получим ответ с помощью функции `get()` из `requests`:

# %%
page = requests.get(main)

# %% [markdown]
# Если мы просто посмотрим на объект, мы ничего особенного не увидим:

# %%
page
# Out:
# <Response [200]>

# %% [markdown]
# Объект page имеет тип `Response` и скрыт от наших глаз. Однако при его вызове мы видим число 200 – это код результата, который означает, что страница благополучно загружена.

# %% [markdown]
# У объекта типа `Response` есть атрибут `.text`, в котором хранится исходный код страницы, который мы можем посмотреть, нажав *Ctrl+U* в Chrome:

# %%
page.text
# Out:
# '<!DOCTYPE html>\n<html prefix="og: http://ogp.me/ns#" lang="ru">\n<head>\n  <meta charset="utf-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1">\n  <title>N + 1: научные статьи, новости, открытия</title>\n  <link href="/front-build/css/main.css" rel="stylesheet">\n  <link href="/front-build/css/app.css?v=1" rel="stylesheet">\n  \n  <link rel="icon" href="/images-new/favicon-bw.png"/>\n\n  <link rel="canonical" href="https://nplus1.ru">\n\n  <meta name="yandex-verification" content="8c90b02c84ac3b72"/>\n  <meta name="pmail-verification" content="b419949322895fc9106e24ed01be58ac">\n\n  <script>window.yaContextCb = window.yaContextCb || []</script>\n  <script src="https://yandex.ru/ads/system/context.js" async></script>\n\n  \n\n  <meta property="og:site_name" content="N + 1: научные статьи, новости, открытия"/>\n  <meta property="og:title" content="N + 1: научные статьи, новости, открытия"/>\n  <meta property="og:image" content="https://nplus1.ru/images-new/share_snippet.png"/>\n  <meta property="og:url" content="https://nplus1.ru"/>\n  <meta property="og:description" content="N + 1: научные статьи, новости, открытия"/>\n  <meta property="og:type" content=""/>\n\n  \n  <meta name="twitter:card" content="summary_large_image">\n  <meta name="twitter:site" content="@nplusodin"/>\n  <meta name="twitter:title" content="N + 1: научные статьи, новости, открытия"/>\n  <meta name="twitter:description" content="N + 1: научные статьи, новости, открытия"/>\n  <meta name="twitter:image" content="https://nplus1.ru/images-new/share_snippet.png"/>\n\n  <link rel=\'alternate\' type=\'application/rss+xml\' title=\'RSS\' href=\'https://nplus1.ru/rss\'>\n\n  \n  \n  \n  \n\n\n  \n  \n  \n\n  \n\n</head>\n<body class="antialiased">\n<div id="appfront" class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray">\n\n  <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50"\n        data-ref-header\n        ref="headerRef">\n\n  \n  <div class="border-b border-main-gray h-full">\n    <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full"\n         data-ref-header-container\n         ref="headerContainerRef">\n\n      <button aria-label="Go" data-ref-header-menu-btn\n              ref="headerMenuBtnRef"\n              id="topMenuBtn"\n              @click="menuOpen"\n              class="w-7.5 h-7.5">\n        <template v-if="isOpenDesktopMenu || isOpenMobileMenu">\n          <svg class="w-full h-full">\n            <use xlink:href="#n1_cross_menu"></use>\n          </svg>\n        </template>\n        <template v-else>\n          <svg class="w-full h-full">\n            <use xlink:href="#n1_burger"></use>\n          </svg>\n        </template>\n      </button>\n\n      <div>\n                    <img src="/images-new/logo.svg" height="23" width="57" alt="as">\n                  </div>\n\n      <a href="/search" class="w-7.5 h-7.5">\n        <svg class="w-full h-full">\n          <use xlink:href="#n1_pupa"></use>\n        </svg>\n      </a>\n    </div>\n  </div>\n\n  <nav v-if="isOpenDesktopMenu" id="navMenu" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden"\n       :style="stylesNavDesktop">\n    <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">\n      <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">\n\n        \n        <!--\n        <a @click.native="menuClose"\n           class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"\n           href="/lk">\n          <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">\n            <use xlink:href="#n1_person"></use>\n          </svg>\n          <span>Личный кабинет</span>\n        </a>\n        -->\n        \n        <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:t ...

# %% [markdown]
# Результат выше – это обычная строка, тип string. Выполнять поиск по такой строке неудобно, поэтому преобразуем эту строку в объект типа `BeautifulSoup`, который позволяет выполнять поиск по тегам:

# %%
soup = BeautifulSoup(page.text)

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# Чтобы сгрузить все новости с главной страницы сайта, нужно собрать все ссылки на страницы с этими новостями. Ссылки в html-файле всегда заключены в тэг `<a></a>` и имеют атрибут `href`. Найдем кусочки кода HTML, соответствующие всем ссылкам на главной странице сайта:

# %%
links_raw = soup.find_all("a") 
links_raw[10:20]  # несколько штук для примера
# Out:
# [<a class="hover:underline transition-colors duration-75" href="/search/empty/768">Генетика</a>,
#  <a class="hover:underline transition-colors duration-75" href="/search/empty/890">Математика</a>,
#  <a class="hover:underline transition-colors duration-75" href="/search/empty/871">Космонавтика</a>,
#  <a class="hover:underline transition-colors duration-75" href="/search/empty/876">Археология</a>,
#  <a class="hover:underline transition-colors duration-75" href="/search/empty/775">Нейронауки</a>,
#  <a class="hover:underline transition-colors duration-75" href="/search/empty/767">На мышах</a>,
#  <a class="hover:underline transition-colors duration-75" href="/search/empty/771">Звук</a>,
#  <a class="hover:underline transition-colors duration-75" href="/search/empty/772">Красота</a>,
#  <a class="hover:underline transition-colors duration-75" href="/search/empty/778">Научные закрытия</a>,
#  <a class="hover:underline transition-colors duration-75" href="/search/empty/917">ИИ спешит на помощь</a>]

# %% [markdown]
# В коде выше мы использовали метод `.find_all()`, который выполняет поиск по заданному тэгу и возвращает список частей кода HTML с выбранным тэгом. Каждый элемент возвращаемого списка имеет тип `BeautifulSoup` и структуру, очень похожую на словарь. Например, ссылка `<a class="hover:underline transition-colors duration-75" href="/search/empty/768">Генетика</a>` изнутри выглядит как словарь следующего вида:
#
#     {'href' : '/search/empty/768',
#      'class' : 'hover:underline transition-colors duration-75'}.

# %% [markdown]
# Как мы помним, значение по ключу из словаря можно вызвать с помощью метода `.get()`. Давайте извлечем значения по ключу `href` из каждого элемента списка `links`:

# %%
links = [li.get("href") for li in links_raw] 
links[10:20]  # несколько штук для примера
# Out:
# ['/search/empty/768',
#  '/search/empty/890',
#  '/search/empty/871',
#  '/search/empty/876',
#  '/search/empty/775',
#  '/search/empty/767',
#  '/search/empty/771',
#  '/search/empty/772',
#  '/search/empty/778',
#  '/search/empty/917']

# %% [markdown]
# Ссылок в списке выше много. Но нам нужны только новости – ссылки, которые начинаются с `https://nplus1.ru/news`. Создадим пустой список `news` и будем добавлять в него только ссылки, которые удовлетворяют этому условию.

# %%
news = []
for li in links:
    if "https://nplus1.ru/news/" in li:
        news.append(li)

# %% [markdown]
# Первая ссылка ведет не совсем на новость, скорее, на объявление, поэтому давайте ее уберем:

# %%
news = news[1:]

# %% [markdown]
# Теперь наша задача сводится к следующему: изучить одну страницу с новостью, научиться из нее вытаскивать текст и всю необходимую информацию, а потом применить весь набор действий к каждой ссылке из `news` в цикле. Посмотрим на новость с индексом 0, у вас может быть другая, новости обновляются.

# %%
link0 = news[0]
print(link0)
# Out:
# https://nplus1.ru/news/2022/11/03/ancient-dna

# %% [markdown]
# Отправим запрос к этой странице с одной новостью и обработаем исходный код страницы:

# %%
page0 = requests.get(link0)
soup0 = BeautifulSoup(page0.text)

# %% [markdown]
# Попробуем найти заголовок новости. Изучив исходный код страницы, заметим, что он находится в разных местах страницы. Возьмем самый простой вариант – тэг `<title>`:

# %%
# find() вместо find_all(), так как результат точно будет один
# незачем писать soup0.find_all("title")[0] для извлечения единственного элемента списка,
# если можно сразу вернуть этот единственный элемент

soup0.find("title")
# Out:
# <title>Население Южной Америки разделилось на две группы не менее десяти тысяч лет назад</title>

# %% [markdown]
# Извлечем текст, который заключен внутри тэгов:

# %%
title = soup0.find("title").text
title
# Out:
# 'Население Южной Америки разделилось на\xa0две группы не\xa0менее десяти тысяч лет назад'

# %% [markdown]
# Найдем теперь имя автора. Заметим, что оно находится в тэге `<meta>`, причем не просто в `<meta>`, а с атрибутом `name`, равным `mediator_author`. Чтобы учесть это уточнение в поиске, подадим на вход `.find()` словарь с названием атрибута и его значением:

# %%
soup0.find("meta", {"name" : "mediator_author"})
# Out:
# <meta content="Михаил Подрезов" name="mediator_author"/>

# %% [markdown]
# Осталось извлечь имя автора из `content` по аналогии с тем, как мы ранее извлекали ссылку из `href`. Используем метод `.get()`:

# %%
author = soup0.find("meta", {"name" : "mediator_author"}).get("content")

# %% [markdown]
# Аналогичным образом извлечем дату публикации новости:

# %%
date = soup0.find("meta", {"itemprop" : "datePublished"}).get("content")

# %% [markdown]
# С остальными характеристиками – сложностью и рубриками – все более интересно. С одной стороны, их можно найти точно так же по тэгам и атрибутам, но для надежности (не все названия атрибутов здесь понятны и гарантируют уникальность) давайте сузим пространство для поиска и будем искать их не по всей странице, а в пределах какого-нибудь раздела. Такой раздел есть, он имеет очень длинное значение атрибута `class`:

# %%
div = soup0.find("div",
                 {"class" : "flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9"})
div
# Out:
# <div class="flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9">
# <span class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center">
# <span class="group-hover:text-main transition-colors duration-75">10:02</span>
# </span>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/news/2022/11/03">
# <span class="group-hover:text-main transition-colors duration-75">03.11.22</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">3.9</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/search/empty/877">
# <span class="group-hover:text-main transition-colors duration-75">Антропология</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/search/empty/876">
# <span class="group-hover:text-main transition-colors duration-75">Археология</span>
# </a>
# </div>

# %% [markdown]
# В этом разделе встречаются более мелкие части с тэгами `span`, в которых хранится дата, сложность статьи и рубрики. К сожалению, сайт сейчас в процессе перехода к новой структуре и новому дизайну, поэтому не всегда последовательность элементов будет такой (где-то будет вклиниваться время публикации статьи), но каким-то быстрым способом мы с этой проблемой сейчас не справимся. Поэтому отберем элементы как есть:

# %%
diffc = div.find_all("span")[1]
rubs_raw = div.find_all("span")[2:]

# %%
print(diffc)
print(rubs_raw)
# Out:
# <span class="group-hover:text-main transition-colors duration-75">10:02</span>
# [<span class="group-hover:text-main transition-colors duration-75">03.11.22</span>, <span class="group-hover:text-main transition-colors duration-75">3.9</span>, <span class="group-hover:text-main transition-colors duration-75">Антропология</span>, <span class="group-hover:text-main transition-colors duration-75">Археология</span>]

# %% [markdown]
# Теперь давайте извлечем из блоков кода HTML с рубриками текст с названиями рубрик:

# %%
rubs = [r.text for r in rubs_raw]
rubs
# Out:
# ['03.11.22', '3.9', 'Антропология', 'Археология']

# %% [markdown]
# Склеим их в одну строку по запятой:

# %%
rubs_text = ", ".join(rubs)

# %% [markdown]
# Осталось аналогичным образом сохранить самое главное – текст новости. Заметим, что его нужно собирать по абзацам – по тэгам `<p>` с атрибутом `class`, равным `mb-6`:

# %%
pars_raw = soup0.find_all("p", {"class" : "mb-6"}) 
pars_raw
# Out:
# [<p class="text-36 md:text-44 xl:text-54 font-spectral text-main-gray mb-6">Похоже, это произошло в андском регионе</p>,
#  <p class="mb-6">Палеогенетики секвенировали древнюю ДНК двух людей, останки которых нашли в Бразилии. Объединив полученные данные с ранее опубликованными геномами, они пришли к выводу, что как минимум десять тысяч лет назад древнейшее население Южной Америки разделилось на две популяции. Вероятно, это событие произошло в андском регионе. После чего одна часть дала начало населению Южного конуса, а другая — популяциям атлантического побережья. Результаты исследования <a href="https://doi.org/10.1098/rspb.2022.1078">опубликованы</a> в журнале <em>Proceedings of the Royal Society B: Biological Sciences</em>.</p>,
#  <p class="mb-6">Время и маршруты заселения Америки — тема весьма дискуссионная. На протяжении долгого времени древнейшим населением этого континента считались представители археологической <a href="https://nplus1.ru/news/2021/11/22/clovis-culture">культуры Кловис</a>, существовавшей около 13,5–10,8 тысячи лет назад. Но последующие открытия показали, что люди оказались в Америке раньше. С уверенностью можно говорить о том, что первые американцы <a href="https://nplus1.ru/news/2020/07/17/pre-clovis-dung">расселялись</a> к югу от ледниковых щитов уже 16–15 тысяч лет назад. При этом регулярно появляются гораздо более древние свидетельства человеческой активности на этом континенте. Например, в минувшем году в США <a href="https://nplus1.ru/news/2021/09/23/ancient-footprints">нашли</a> отпечатки человеческих ног возрастом около 21–23 тысяч лет, а в этом — <a href="https://nplus1.ru/news/2022/08/03/human-occupation-america">обнаружили</a> кости мамонтов со следами разделки возрастом около 37 тысяч лет. В то же время подобные находки нередко оспариваются, как это <a href="https://nplus1.ru/news/2021/11/02/human-occupation-america">произошло</a>, например, с древнейшей стоянкой в Мексике. Кроме того, аналогичных по возрасту человеческих останков в Америке пока не нашли.</p>,
#  <p class="mb-6">Генетические исследования <a href="https://www.corpus.ru/products/aleksandr-markov-ehvolyuciya-cheloveka-kniga-3.htm">показывают</a>, что современное индейское население обеих Америк — потомки древних берингийцев, мигрировавших из Северо-Восточной Азии. Примерно 15 тысяч лет назад эта популяция <a href="https://nplus1.ru/news/2018/11/08/palaeo">разделилась</a> на две, одна из которых быстро заселила Северную Америку, а другая — Южную. В геномах древнего населения Америки нашли примесь и от вымерших популяций людей, причем не только от неандертальцев, но и от денисовцев (например, у девочки, жившей на Аляске около 11,5 тысячи лет назад). Кроме того, у современных индейских племен ученые <a href="https://nplus1.ru/news/2015/07/22/population-Y">обнаружили</a> предковую компоненту, схожую с той, что присутствует у населения Австралазии. Ее происхождение пока требует объяснений.</p>,
#  <p class="mb-6">Джон Линдо (John Lindo) из Университета Эмори совместно с коллегами из Бразилии и США исследовал останки двух человек (Brazil-2 и Brazil-12), найденные в штате Пернамбуку. Анализ показал, что индивид-2 умер 981 ± 23 радиоуглеродных года назад. Время, когда жил другой человек, точно установить не удалось, но ученые отметили, что полученные датировки указывают на период между 888 ± 25 и 4851 ± 30 радиоуглеродных лет назад. Из обоих образцов им также удалось секвенировать древнюю ДНК. Индивид Brazil-2 оказался мужчиной, который был носителем митохондриальной гаплогруппы C1b и Y-хромосомной гаплогруппы Q1b1a1a1. У человека Brazil-12 они определили митохондриальную гаплогруппу D1a2.</p>,
#  <p class="mb-6">Затем ученые привлекли данные по немногочисленным раннее опубликованным древним геномам из Америки, включая два генома из Уругвая (CH13 и CH19B), статья о которых <a href="https://academic.oup.com/pnasnexus/article/1/2/pgac047/6571940" rel="noreferrer noopener" target="_blank">вышла</a> в этом году. Метод главных компонент показал, что генетические профили этих людей образуют две клады. Первая — географически связана с тихоокеанским побережьем, вторая — с атлантическим. С помощью моделирования ученые пришли к выводу, что первые американцы, оказавшиеся в Южной Америке, разделились на две группы, когда достигли андского региона. Одна часть людей затем дала начало древним популяциям Южного конуса, а другая — первым популяциям, заселившим атлантическое побережье этого континента. По расчетам исследователей, это произошло по крайней мере десять тысяч лет назад.</p>,
#  <p class="mb-6">Среди других результатов работы обращает на себя внимание тот факт, что исследователи вновь обнаружили предковую компоненту, связанную с современным населением Австралазии, в геноме древнего жителя Америки. Кроме того, ожидаемо в геномах этих людей ученые нашли небольшой вклад от вымерших популяций древних людей — неандертальцев и денисовцев. При этом исследование идентичности по происхождению методом IBDmix показало, что у двух индивидов денисовская примесь оказалась больше неандертальской. Это человек из Панамы (PAPV173), живший 650–520 радиоуглеродных лет назад и человек из Уругвая (CH19B), живший около 1450 радиоуглеродных лет назад.</p>,
#  <p class="mb-6">Ранее на <em>N + 1</em> рассказывали о генетическом исследовании останков десяти людей, найденных в мексиканском городе Кампече. <a href="https://nplus1.ru/news/2022/07/13/campeche">Оказалось</a>, что в некрополе раннего колониального периода покоились останки восьми коренных американцев и двух мигрантов. Похоже, одна женщина происходила из Западной Африки, а один мужчина — из Испании.</p>,
#  <p class="text-36 md:text-44 xl:text-54 font-spectral text-main-gray mb-6">Биоархеологи исследовали останки женщины, жившей около двух тысяч лет назад</p>,
#  <p class="mb-6">Биоархеологи исследовали останки пожилой женщины, жившей около двух тысяч лет назад, которые нашли на Оркнейских островах. Оказалось, что на протяжении всей жизни существенную часть ее рациона составляла морская рыба. Это нетипично для жителей Британских островов железного века. Об этом сообщается в пресс-релизе Йоркского университета.</p>]

# %% [markdown]
# Извлечем текст в чистом виде из каждого элемента списка `pars_raw`:

# %%
pars = [p.text for p in pars_raw]

# %% [markdown]
# Склеим полученные строки в одну большую строку через `.join()`, а заодно избавимся от посторонних символов `\xa0`, которые соответствуют неразрывным пробелам, и `\n`, которые соответствуют переходам на новую строку:

# %%
text = " ".join(pars)
text = text.replace("\xa0", " ") 
text = text.replace("\n", " ")

# %% [markdown]
# Теперь все красиво. Напишем функцию для выгрузки информации по одной новости и применим ее к новостям на главной странице.

# %%
def get_news(link0):
    page0 = requests.get(link0)
    soup0 = BeautifulSoup(page0.text) 
    title = soup0.find("title").text
    author = soup0.find("meta", {"name" : "mediator_author"}).get("content") 
    date = soup0.find("meta", {"itemprop" : "datePublished"}).get("content") 
    div = soup0.find("div",
                 {"class" : "flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9"})
    diffc = div.find_all("span")[1].text
    rubs_raw = div.find_all("span")[2:]
    rubs = [r.text for r in rubs_raw]
    rubs_text = ", ".join(rubs)
    pars_raw = soup0.find_all("p", {"class" : "mb-6"}) 
    pars = [p.text for p in pars_raw] 
    text = " ".join(pars)
    text = text.replace("\xa0", " ") 
    return title, author, date, diffc, rubs_text, text

# %% [markdown]
# Чтобы сайт не понял, что мы его автоматически грабим, будем выгружать новости постепенно – с задержкой в 1.5 секунды. Импортируем для этого функцию `sleep` :

# %%
from time import sleep

# %% [markdown]
# Теперь будем применять функцию в цикле к каждой ссылке в `news`, только с одним дополнением – добавленной конструкцией `try-except`, которая позволит продолжать исполнение цикла, если при применении функции Python столкнулся с ошибкой любого вида:

# %%
info = []
for n in news:
    # пробуй исполнить следующий код
    try:
        res = get_news(n)
        info.append(res)
        print(n)
    # если он вызвал ошибку, печатай сообщение и иди дальше
    except:
        print("Something went wrong")
        print(n)
    sleep(1.5)
# Out:
# https://nplus1.ru/news/2022/11/03/ancient-dna
# https://nplus1.ru/news/2022/11/03/Truly-chiral
# https://nplus1.ru/news/2022/11/03/children-videogames
# https://nplus1.ru/news/2022/11/03/height-caffeine
# https://nplus1.ru/news/2022/11/03/ML-Suzuki
# https://nplus1.ru/news/2022/11/03/melanoplus-spretus
# https://nplus1.ru/news/2022/11/03/cats-DNA-human
# https://nplus1.ru/news/2022/11/03/ancient-dna
# https://nplus1.ru/news/2022/11/02/xiaomi-leica
# https://nplus1.ru/news/2022/11/02/over6mets-mortality
# https://nplus1.ru/news/2022/11/02/heating-europe
# https://nplus1.ru/news/2022/11/02/historic-cache-in-ice
# https://nplus1.ru/news/2022/11/02/vortex-stripes
# https://nplus1.ru/news/2022/11/02/vampire-from-usa
# https://nplus1.ru/news/2022/11/02/slavic-hillfort
# https://nplus1.ru/news/2022/11/01/heavy-4
# https://nplus1.ru/news/2022/11/01/birds-size
# https://nplus1.ru/news/2022/11/01/xenicus-gilviventris
# https://nplus1.ru/news/2022/11/01/2022-ap-7
# https://nplus1.ru/news/2022/11/01/ecg-swine2human
# https://nplus1.ru/news/2022/11/01/goodbye-reaxys
# https://nplus1.ru/news/2022/11/01/nudes
# https://nplus1.ru/news/2022/11/01/why-cats-have-nine-lives
# https://nplus1.ru/news/2022/11/01/otus-bikegila
# https://nplus1.ru/news/2022/11/01/family-in-jar
# https://nplus1.ru/news/2022/11/01/mali-malaria-mab
# https://nplus1.ru/news/2022/10/31/echo-hubble
# https://nplus1.ru/news/2022/10/31/bombus-terrestris
# https://nplus1.ru/news/2022/10/28/alan-heritage
# https://nplus1.ru/news/2022/10/19/stone-statue
# https://nplus1.ru/news/2022/10/26/turmeric-damages-liver
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10432/4238979095.py in <module>
#      10         print("Something went wrong")
#      11         print(n)
# ---> 12     sleep(1.5)
#
# KeyboardInterrupt:

# %% [markdown]
# Ура! Несмотря на то, что ближе к концу списка со ссылками мы стали получать сообщения об ошибках, новости за последние несколько дней сгрузились корректно (сайт в разработке, пока небольшие проблемы с унификацией и упорядочиванием ссылок).
#
# Посмотрим на несколько элементов `info`:

# %%
info[10:12]
# Out:
# [('Европа обогнала остальной мир по\xa0темпам нагревания',
#   'Марина Попова',
#   '2022-11-02',
#   '3.1',
#   'Экология и климат',
#   'Это данные доклада Всемирной метеорологической организации по парниковым газам Европа получила статус самого быстро нагревающегося региона мира: в течение последних 30 лет она нагревалась на 0,5 градуса Цельсия каждые 10 лет, то есть в среднем в два раза интенсивнее, чем другие регионы. Ущерб ее экономике от экстремальных климатических событий в 2021 году превысил 50 миллиардов долларов. Люди и экосистемы в регионе пострадали от волн жары, наводнений, засух и масштабных природных пожаров. Вместе с тем Европа достигла определенных успехов в снижении антропогенных выбросов парниковых газов. К таким выводам пришли авторы доклада Всемирной метеорологической организации и Европейской программы дистанционного зондирования Земли Copernicus о состоянии климата в Европе в 2021 году, пресс-релиз которого поступил в редакцию N + 1. Всемирная метеорологическая организация (ВМО) ежегодно публикует доклады об изменениях климата. Данные, которые позволяют отслеживать такие изменения, поступают из Глобальной службы атмосферы ВМО и партнерских сетей — в их состав входят сотни метеорологических станций по всему миру. Сегодня ВМО опубликовала свой первый ежегодный доклад о состоянии климата в Европе в 2021 году, подготовленный совместно с Европейской программой дистанционного зондирования Земли Copernicus. Согласно докладу, с 1991 по 2021 годы средняя температура воздуха в Европе поднималась на 0,5 градуса Цельсия за каждые 10 лет, и на данный момент Европа является самым быстро нагревающимся регионом в мире. В 2021 году был установлен новый рекорд: 11 августа во время волны жары температура воздуха возле Сиракуз на Сицилии достигла 48,8 градуса Цельсия. Среднее содержание морского льда в европейской части Арктики в сентябре 2021 побило исторический месячный рекорд и было на 37 процентов ниже, чем в среднем в за 1981–2010 годы в этом месяце. В 2021 году в экстремальные климатические события в Европе затронули приблизительно 510 тысяч человек и нанесли суммарный ущерб экономике не менее 50 миллиардов долларов. Засухи и высокие температуры привели к масштабным природным пожарам. Площадь возгорания в таких странах как Кипр, Франция, Греция, Израиль, Италия, Ливан (относится в европейскому округу наблюдения ВМО), Черногория и Турция была в три и более раз выше, чем в среднем за 2006–2020 годы. Авторы доклада назвали все более частые, интенсивные и разрушительные природные пожары, возникающие в Европе, главной угрозой для региональных экосистем. Вместе с тем весной 2021 года в Европе случилась вспышка экстремальных заморозков, которая повредила посевы и нанесла сельскому хозяйству в регионе ущерб в 4,6 миллиарда долларов.  Большое внимание в докладе уделяется общественному здравоохранению. По данным Европейского регионального бюро Всемирной организации здравоохранения, около полумиллиона случаев преждевременной смерти в Европе в 2019 году были вызваны антропогенным загрязнением атмосферного воздуха мелкодисперсными частицами, значительная часть которых была непосредственно связана со сжиганием ископаемого топлива. Наиболее опасными для здоровья людей, проживающих в Европе, остаются волны жары. Уязвимость населения к ним усугубляется старением населения и ростом урбанизации (о влиянии городской жары на население можно почитать здесь). На фоне потепления растут и риски трансмиссивных заболеваний, например, увеличения частоты случаев болезни Лайма, которую распространяет клещ Ixodes ricinus, и роста числа аллергических заболеваний за счет увеличения продолжительности сезона пыльцы (он уже стал дольше в Северной Америке). Авторы отметили также возможное нарастание проблем населения с психическим здоровьем на фоне стремительного изменения климата. Но есть и некоторые хорошие новости. Ряд европейских стран добились значительных успехов в сокращении антропогенных выбросов парниковых газов. Например, в Евросоюзе такие выбросы снизились на 31 процент по отношению к уровню 1990 года, и ожидается, что к 2030 году они снизятся уже на 55 процентов, то есть еще ...
#  ('В\xa0канадском леднике нашли 85-летний тайник с\xa0фотоаппаратурой',
#   'Надежда Чекасина',
#   '2022-11-02',
#   '1.2',
#   'Археология',
#   'Его оставил картограф Брэдфорд Уошберн в 1937 году Исследовательская экспедиция обнаружила тайник, закопанный в леднике Уолша, который находится на территории национального парка и заповедника Клуэйн в Канаде, сообщает Teton Gravity Research. Исторический тайник, содержащий фотоаппаратуру и снаряжение, 85 лет назад в леднике оставил знаменитый фотограф и картограф Брэдфорд Уошберн. В 1937 знаменитые альпинисты Брэдфорд Уошберн и Роберт Бейтс предприняли попытку восхождения на самую высокую в то время непокоренную вершину Северной Америки, гору Лукейния. Вершина высотой 5226 метров располагается в труднодоступной местности в горах Святого Ильи на границе территории Юкон на северо-западе Канады и Аляски. За несколько лет до этого Уошберн уже исследовал Юкон, первым сделал аэрофотоснимки местности и нанес на карту большинство ледников и пиков этого региона. В июне 1937 года альпинисты высадились на леднике и начали восхождение на Лукейнию. Несмотря на тяжелые погодные условия, они достигли вершины. Во время спуска они прошли около 240 километров по весеннему таянию, пока не достигли небольшого поселения в Юконе. Исследователям пришлось оставить свое оборудование в закопанном в лед тайнике: камеры, аэрофотокамеры, геодезическое оборудование и альпинистское снаряжение.  Спустя 85 лет лыжник и исследователь гор Гриффин Пост (Griffin Post) собрал экспедицию, чтобы найти утерянный тайник на леднике. В многомесячных поисках им помогала гляциолог из Университета Оттавы Дора Меджицка (Dora Medrzycka) со своими коллегами. Поиски стартовали в апреле 2022 года, во время исследований команда передвигалась пешком, на лыжах и сноубордах. Чтобы получить представление о том, где располагался лагерь Уошберна и Бейтса, исследователям пришлось внимательно изучить фотографии с места, которые уцелели во время экспедиции Уошберна. Гляциологи помогали определить нынешнее местоположение тайника, которое изменилось с движением ледника. Однако первые поиски не увенчались успехом. Во время второй поездки к леднику Меджицка предложила новую гипотезу о том, где могут находиться артефакты. Обычно ледники движутся с постоянной скоростью из года в год, однако ледник Уолша относится к редким пульсирующим ледникам. Такие ледники испытывают единовременные или регулярные подвижки-серджи — резкие увеличения скорости движения. Меджицка обратила внимание на ледниковые обломки, которые проходили через всю длину ледника и предположила, что они образовались из-за серджа. Она предположила, как ледник мог двигаться в прошлом, и на основе наблюдений рассчитала новые координаты, где мог быть обнаружен тайник. Это было примерно в 22 километрах от места, где Уошберн оставил его.  Наконец, тайник был обнаружен. Археологи извлекли его из-подо льда и обнаружили там аэрофотокамеру Fairchild F-8 Уошберна, две кинокамеры с пленкой внутри, трекинговые палки, палатки и другое снаряжение. Исследователи планируют проявить пленку, чтобы получить данные о леднике, которые зафиксировал Уошберн. По их словам, результаты экспедиции помогут лучше понять, как движутся ледники и изменился ли и как поток ледника Уолша.  В последнее время археологи часто обнаруживают вытявшие из-подо льда артефакты. Недавно в Норвегии нашли древко средневековой стрелы, которое несколько столетий было похоронено под снегом и льдом. Также археологи сообщали о вытаявших древних туфлях, одной и которых было 1700 лет, а другая оказалась древнейшим предметом обуви, найденным в Норвегии — она относится к бронзовому веку. Археолог Михаил Шуньков сообщил, что в нынешнем сезоне в Денисовой пещере нашли два зуба древних гоминин, об одном из которых стало известно еще в июле нынешнего года. По словам ученого, один новый моляр представляет собой копию находки Денисова-4 — денисовца, жившего около 84,1–55,2 тысячи лет назад. Об этом сообщило издание Сибирского отделения РАН «Наука в Сибири».')]

# %% [markdown]
# Финальный штрих – импортируем `pandas` и преобразуемый полученный список кортежей в датафрейм:

# %%
import pandas as pd

# %%
df = pd.DataFrame(info)
df.head()
# Out:
#                                                    0                  1  \
# 0  Население Южной Америки разделилось на две гру...    Михаил Подрезов
# 1  Хиральность фононов в киновари оказалась истинной     Марат Хамадеев
# 2  Маленькие геймеры отличились высоким уровнем р...  Анастасия Ляшенко
# 3  Прием кофеина во время беременности отнял пару...   Сергей Задворьев
# 4  Машинное обучение помогло найти оптимальные ус...        Михаил Бойм
#
#             2      3                                        4  \
# 0  2022-11-03  10:02  03.11.22, 3.9, Антропология, Археология
# 1  2022-11-03  17:11                    03.11.22, 8.2, Физика
# 2  2022-11-03  16:19                03.11.22, 3.2, Психология
# 3  2022-11-03  15:46                  03.11.22, 2.5, Медицина
# 4  2022-11-03  15:25                     03.11.22, 7.1, Химия
#
#                                                    5
# 0  Похоже, это произошло в андском регионе Палеог...
# 1  А связь между их угловым и псевдоугловым момен...
# 2  Результаты не зависели от пола ребенка Америка...
# 3  Даже в восемь лет дети от матерей, получавших ...
# 4  Выход описанных в литературе реакций повысился...

# %% [markdown]
# Не везде информация сгрузилась корректно, есть проблемы унификации, можно потом поправить это, написав функцию и применив ее через `.apply()` к соответствующим столбцам.
#
# А пока добавим содержательные названия столбцов и выгрузим датафрейм в файл:

# %%
df.columns = ["title", "author", "date", "diffc", "rubrics", "text"]
df.to_excel("nplus1.xlsx")
